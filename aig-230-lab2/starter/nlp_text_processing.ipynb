# %% [markdown]
# # AIG 230 – Week 2 Lab
# ## From Raw Text to Corpus: Tokenization, Normalization, and Vocabulary
#
# Industry Context: Exploring the State of the Union Corpus

# %% [markdown]
# ## Learning Objectives
# - Understand raw text, documents, and corpora
# - Explore a real-world corpus
# - Compare NLTK and spaCy preprocessing pipelines
# - Perform tokenization, normalization, and vocabulary analysis

# %%
pip list
# Out:
# Package                    Version
# -------------------------- -----------
# absl-py                    2.3.1
# accelerate                 1.12.0
# aiohappyeyeballs           2.6.1
# aiohttp                    3.13.3
# aiosignal                  1.4.0
# annotated-types            0.7.0
# anyio                      4.12.1
# argon2-cffi                25.1.0
# argon2-cffi-bindings       25.1.0
# arrow                      1.4.0
# asttokens                  3.0.1
# astunparse                 1.6.3
# async-lru                  2.0.5
# attrs                      25.4.0
# babel                      2.17.0
# beautifulsoup4             4.14.3
# bleach                     6.3.0
# blis                       1.3.3
# boto3-stubs                1.42.26
# botocore-stubs             1.42.26
# catalogue                  2.0.10
# certifi                    2026.1.4
# cffi                       2.0.0
# charset-normalizer         3.4.4
# click                      8.3.1
# cloudpathlib               0.23.0
# cloudpickle                3.1.2
# colorama                   0.4.6
# comm                       0.2.3
# confection                 0.1.5
# contourpy                  1.3.3
# cycler                     0.12.1
# cymem                      2.0.13
# datasets                   4.4.2
# debugpy                    1.8.19
# decorator                  5.2.1
# defusedxml                 0.7.1
# dill                       0.4.0
# distro                     1.9.0
# en_core_web_sm             3.8.0
# executing                  2.2.1
# fastjsonschema             2.21.2
# fastuuid                   0.14.0
# filelock                   3.20.3
# flatbuffers                25.12.19
# fonttools                  4.61.1
# fqdn                       1.5.1
# frozenlist                 1.8.0
# fsspec                     2025.10.0
# gast                       0.7.0
# google-pasta               0.2.0
# grpcio                     1.76.0
# gym                        0.26.2
# gym-notices                0.1.0
# h11                        0.16.0
# h5py                       3.15.1
# httpcore                   1.0.9
# httpx                      0.28.1
# huggingface-hub            0.36.0
# idna                       3.11
# importlib_metadata         8.7.1
# iniconfig                  2.3.0
# ipykernel                  7.1.0
# ipython                    9.9.0
# ipython_pygments_lexers    1.1.1
# ipywidgets                 8.1.8
# isoduration                20.11.0
# jedi                       0.19.2
# Jinja2                     3.1.6
# jiter                      0.12.0
# joblib                     1.5.3
# json5                      0.13.0
# jsonpointer                3.0.0
# jsonschema                 4.26.0
# jsonschema-specifications  2025.9.1
# jupyter                    1.1.1
# jupyter_client             8.8.0
# jupyter-console            6.6.3
# jupyter_core               5.9.1
# jupyter-events             0.12.0
# jupyter-lsp                2.3.0
# jupyter_server             2.17.0
# jupyter_server_terminals   0.5.3
# jupyterlab                 4.5.2
# jupyterlab_pygments        0.3.0
# jupyterlab_server          2.28.0
# jupyterlab_widgets         3.0.16
# keras                      3.13.0
# kiwisolver                 1.4.9
# lark                       1.3.1
# libclang                   18.1.1
# lion-pytorch               0.2.3
# litellm                    1.80.16
# Markdown                   3.10
# markdown-it-py             4.0.0
# MarkupSafe                 3.0.3
# matplotlib                 3.10.8
# matplotlib-inline          0.2.1
# mdurl                      0.1.2
# mistune                    3.2.0
# mitdeeplearning            0.7.5
# ml_dtypes                  0.5.4
# mpmath                     1.3.0
# multidict                  6.7.0
# multiprocess               0.70.18
# murmurhash                 1.0.15
# mypy-boto3-bedrock-runtime 1.42.3
# namex                      0.1.0
# nbclient                   0.10.4
# nbconvert                  7.16.6
# nbformat                   5.10.4
# nest-asyncio               1.6.0
# networkx                   3.6.1
# nltk                       3.9.2
# notebook                   7.5.1
# notebook_shim              0.2.4
# numpy                      2.2.6
# openai                     2.15.0
# opencv-python              4.12.0.88
# opik                       1.9.80
# opt_einsum                 3.4.0
# optree                     0.18.0
# overrides                  7.7.0
# packaging                  25.0
# pandas                     2.3.3
# pandocfilters              1.5.1
# parso                      0.8.5
# peft                       0.18.1
# pillow                     12.1.0
# pip                        23.1.2
# platformdirs               4.5.1
# pluggy                     1.6.0
# preshed                    3.0.12
# prometheus_client          0.23.1
# prompt_toolkit             3.0.52
# propcache                  0.4.1
# protobuf                   6.33.4
# psutil                     7.2.1
# pure_eval                  0.2.3
# pyarrow                    22.0.0
# pycparser                  2.23
# pydantic                   2.12.5
# pydantic_core              2.41.5
# pydantic-settings          2.12.0
# Pygments                   2.19.2
# pyparsing                  3.3.1
# pytest                     9.0.2
# python-dateutil            2.9.0.post0
# python-dotenv              1.2.1
# python-json-logger         4.0.0
# pytz                       2025.2
# pywinpty                   3.0.2
# PyYAML                     6.0.3
# pyzmq                      27.1.0
# RapidFuzz                  3.14.3
# referencing                0.37.0
# regex                      2025.11.3
# requests                   2.32.5
# rfc3339-validator          0.1.4
# rfc3986-validator          0.1.1
# rfc3987-syntax             1.1.0
# rich                       14.2.0
# rpds-py                    0.30.0
# safetensors                0.7.0
# Send2Trash                 2.0.0
# sentry-sdk                 2.49.0
# setuptools                 65.5.0
# six                        1.17.0
# smart_open                 7.5.0
# sniffio                    1.3.1
# soupsieve                  2.8.1
# spacy                      3.8.11
# spacy-legacy               3.0.12
# spacy-loggers              1.0.5
# srsly                      2.5.2
# stack-data                 0.6.3
# sympy                      1.14.0
# tenacity                   9.1.2
# tensorboard                2.20.0
# tensorboard-data-server    0.7.2
# tensorflow                 2.20.0
# termcolor                  3.3.0
# terminado                  0.18.1
# thinc                      8.3.10
# tiktoken                   0.12.0
# tinycss2                   1.4.0
# tokenizers                 0.22.2
# torch                      2.9.1
# tornado                    6.5.4
# tqdm                       4.67.1
# traitlets                  5.14.3
# transformers               4.57.5
# typer-slim                 0.21.1
# types-awscrt               0.31.0
# types-s3transfer           0.16.0
# typing_extensions          4.15.0
# typing-inspection          0.4.2
# tzdata                     2025.3
# uri-template               1.3.0
# urllib3                    2.6.3
# uuid6                      2025.0.1
# wasabi                     1.1.3
# wcwidth                    0.2.14
# weasel                     0.4.3
# webcolors                  25.10.0
# webencodings               0.5.1
# websocket-client           1.9.0
# Werkzeug                   3.1.5
# wheel                      0.45.1
# widgetsnbextension         4.0.15
# wrapt                      2.0.1
# xxhash                     3.6.0
# yarl                       1.22.0
# zipp                       3.23.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: wrapt in c:\users\w1tcher\documents\nlp_assignments\aig230-env\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m spacy download en_core_web_sm

import spacy

nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.1/12.8 MB 3.8 MB/s eta 0:00:04
#      --                                       0.9/12.8 MB 11.7 MB/s eta 0:00:02
#      -------                                  2.5/12.8 MB 19.6 MB/s eta 0:00:01
#      --------------                           4.7/12.8 MB 27.2 MB/s eta 0:00:01
#      --------------------                     6.5/12.8 MB 29.6 MB/s eta 0:00:01
#      -------------------------                8.0/12.8 MB 30.1 MB/s eta 0:00:01
#      -----------------------------            9.4/12.8 MB 30.1 MB/s eta 0:00:01
#      -----------------------------------     11.7/12.8 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 29.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
import spacy
import string
from collections import Counter

nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("state_union")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\W1tcher\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\W1tcher\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\W1tcher\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# True

# %%
# Load spaCy English model
# Run once if needed:
# !python -m spacy download en_core_web_sm

nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Breaking it down:
#
# ```
# spacy.load() - loads a pre-trained language model
# ```
#
# "en_core_web_sm" - the small English model that includes:
#
# - Tokenizer - splits text into words/sentences
# - Part-of-speech tagger - identifies noun, verb, adjective, etc.
# - Dependency parser - analyzes grammatical relationships
# - Named entity recognizer - identifies people, places, organizations
# - Word vectors - semantic meaning of words
#
# nlp = - stores the loaded model in a variable so you can use it to process text

# %% [markdown]
# ## Part 1 – Obtaining the Corpus

# %%
from nltk.corpus import state_union
state_union.fileids()[:10]
# Out:
# ['1945-Truman.txt',
#  '1946-Truman.txt',
#  '1947-Truman.txt',
#  '1948-Truman.txt',
#  '1949-Truman.txt',
#  '1950-Truman.txt',
#  '1951-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1954-Eisenhower.txt',
#  '1955-Eisenhower.txt']

# %% [markdown]
# Each file is a document. The collection is the corpus.

# %%
len(state_union.fileids())
# Out:
# 65

# %% [markdown]
# ## Part 2 – Inspect Raw Text

# %%
sample_file = state_union.fileids()[0]
raw_text = state_union.raw(sample_file)
raw_text[:1000]
# Out:
# "PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS\n \nApril 16, 1945\n\nMr. Speaker, Mr. President, Members of the Congress:\nIt is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.\nOnly yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt. At a time like this, words are inadequate. The most eloquent tribute would be a reverent silence.\nYet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.\nIn His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.\nNo man could possibly fill the tremendous void left by the passing of that noble soul. No words can ease the aching hearts of untold millions of every race, creed and color. The world knows it has lost a heroic champion of justice and freedom.\nTragic fate has thrust upon"

# %%
doc = nlp(raw_text)
doc
# Out:
# PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS
#
# April 16, 1945
#
# Mr. Speaker, Mr. President, Members of the Congress:
# It is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.
# Only yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt. At a time like this, words are inadequate. The most eloquent tribute would be a reverent silence.
# Yet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.
# In His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.
# No man could possibly fill the tremendous void left by the passing of that noble soul. No words can ease the aching hearts of untold millions of every race, creed and color. The world knows it has lost a heroic champion of justice and freedom.
# Tragic fate has thrust upon us grave responsibilities. We must carry on.Our departed leader never looked backward. He looked forward and moved forward. That is what he would want us to do. That is what America will do.
# So much blood has already been shed for the ideals which we cherish, and for which Franklin Delano Roosevelt lived and died, that we dare not permit even a momentary pause in the hard fight for victory.
# Today, the entire world is looking to America for enlightened leadership to peace and progress. Such a leadership requires vision, courage and tolerance. It can be provided only by a united nation deeply devoted to the highest ideals.
# With great humility I call upon all Americans to help me keep our nation united in defense of those ideals which have been so eloquently proclaimed by Franklin Roosevelt.
# I want in turn to assure my fellow Americans and all of those who love peace and liberty throughout the world that I will support and defend those ideals with all my strength and all my heart. That is my duty and I shall not shirk it.
# So that there can be no possible misunderstanding, both Germany and Japan can be certain, beyond any shadow of a doubt, that America will continue the fight for freedom until no vestige of resistance remains!
# We are deeply conscious of the fact that much hard fighting is still ahead of us.
# Having to pay such a heavy price to make complete victory certain, America will never become a party to any plan for partial victory!
# To settle for merely another temporary respite would surely jeopardize the future security of all the world.
# Our demand has been, and it remains-Unconditional Surrender! We will not traffic with the breakers of the peace on the terms of the peace.
# The responsibility for making of the peace-and it is a very grave responsibility-must rest with the defenders of the peace. We are not unconscious of the dictates of humanity. We do not wish to see unnecessary or unjustified suffering. But the laws of Go d and of man have been violated and the guilty must not go unpunished. Nothing shall shake our determination to punish the war criminals even though we must pursue them to the ends of the earth.
# Lasting peace can never be secured if we permit our dangerous opponents to plot future wars with impunity at any mountain retreat - however distant.
# In this shrinking world, it is futile to seek safety behind geographical barriers. Real security will be found only in law and in justice.
# Here in America, we have labored long and hard to achieve a social order worthy of our great heritage. In our time, tremendous progress has been made toward a really democratic way of life. Let me assure the forward-looking people of America that there w ill be no relaxation in our efforts to improve the lot of the common people.
# In the difficult days ahead, unquestionably we shall face problems of staggering proportions. However, with the faith of our fathers in our hearts, we do not fear the future.
# On the battlefields, we have frequently faced overwhelming odds - and won! At home, Americans will not be less resolute! We shall never cease our struggle to preserve and maintain our American way of life.
# At this moment, America, along with her brave Allies, is paying again a heavy price for the defense of our freedom. With characteristic energy, we are assisting in the liberation of entire nations. Gradually, the shackles of slavery are being broken by t he forces of freedom.
# All of us are praying for a speedy victory. Every day peace is delayed costs a terrible toll.
# The armies of liberation today are bringing to an end Hitler's ghastly threat to dominate the world. Tokyo rocks under the weight of our bombs.
# The grand strategy of the United Nations' war has been determined - due in no small measure to the vision of our departed Commander in Chief. We are now carrying out our part of that strategy under the able direction of Admiral Leahy, General Marshall, A dmiral King, General Arnold, General Eisenhower, Admiral Nimitz and General MacArthur.
# I want the entire world to know that this direction must and will remain-unchanged and unhampered!
# Our debt to the heroic men and valiant women in the service of our country can never be repaid. They have earned our undying gratitude. America will never forget their sacrifices. Because of these sacrifices, the dawn of justice and freedom throughout th e world slowly casts its gleam across the horizon.
# Our forefathers came to our rugged shores in search of religious tolerance, political freedom and economic opportunity. For those fundamental rights, they risked their lives. We well know today that such rights can be preserved only by constant vigilance , the eternal price of liberty!
# Within an hour after I took the oath of office, I announced that the San Francisco Conference would proceed. We will face the problems of peace with the same courage that we have faced and mastered the problems of war.
# In the memory of those who have made the supreme sacrifice-in the memory of our fallen President-we shall not fail!
# It is not enough to yearn for peace. We must work, and if necessary, fight for it. The task of creating a sound international organization is complicated and difficult. Yet, without such organization, the rights of man on earth cannot be protected. Machi nery for the just settlement of international differences must be found. Without such machinery, the entire world will have to remain an armed camp. The world will be doomed to deadly conflict, devoid of hope for real peace.
# Fortunately, people have retained hope for a durable peace. Thoughtful people have always had faith that ultimately justice must triumph. Past experience surely indicates that, without justice, an enduring peace becomes impossible.
# In bitter despair, some people have come to believe that wars are inevitable. With tragic fatalism, they insist that wars have always been, of necessity, and of necessity wars always will be. To such defeatism, men and women of good will must not and can not yield. The outlook for humanity is not so hopeless.
# During the dark hours of this horrible war, entire nations were kept going by something intangible-hope! When warned that abject submission offered the only salvation against overwhelming power, hope showed the way to victory.
# Hope has become the secret weapon of the forces of liberation!
# Aggressors could not dominate the human mind. As long as hope remains, the spirit of man will never be crushed.
# But hope alone was not and is not sufficient to avert war. We must not only have hope but we must have faith enough to work with other peace-loving nations to maintain the peace. Hope was not enough to beat back the aggressors as long as the peace-loving nations were unwilling to come to each other's defense. The aggressors were beaten back only when the peace-loving nations united to defend themselves.
# If wars in the future are to be prevented the nations must be united in their determination to keep the peace under law.
# Nothing is more essential to the future peace of the world than continued cooperation of the nations which had to muster the force necessary to defeat the conspiracy of the Axis powers to dominate the world.
# While these great states have a special responsibility to enforce the peace, their responsibility is based upon the obligations resting upon all states, large and small, not to use force in international relations except in the defense of law. The respon sibility of the great states is to serve and not to dominate the world.
# To build a foundation of enduring peace we must not only work in harmony with our friends abroad, but we must have the united support of our own people.
# Even the most experienced pilot cannot bring a ship safely into harbor, unless he has the full cooperation of the crew. For the benefit of all, every individual must do his duty.
# I appeal to every American, regardless of party, race, creed, or color, to support our efforts to build a strong and lasting United Nations Organization.
# You, the Members of the Congress, surely know how I feel. Only with your help can I hope to complete one of the greatest tasks ever assigned to a public servant. With Divine guidance, and your help, we will find the new passage to a far better world, a kindly and friendly world, with just and lasting peace.
# With confidence, I am depending upon all of you.
# To destroy greedy tyrants with dreams of world domination, we cannot continue in successive generations to sacrifice our finest youth.
# In the name of human decency and civilization, a more rational method of deciding national differences must and will be found!
# America must assist suffering humanity back along the path of peaceful progress. This will require time and tolerance. We shall need also an abiding faith in the people, the kind of faith and courage which Franklin Delano Roosevelt always had!
# Today, America has become one of the most powerful forces for good on earth. We must keep it so. We have achieved a world leadership which does not depend solely upon our military and naval might.
# We have learned to fight with other nations in common defense of our freedom. We must now learn to live with other nations for our mutual good. We must learn to trade more with other nations so that there may be-for our mutual advantage-increased product ion, increased employment and better standards of living throughout the world.
# May we Americans all live up to our glorious heritage.
# In that way, America may well lead the world to peace and prosperity.
# At this moment, I have in my heart a prayer. As I have assumed my heavy duties, I humbly pray Almighty God, in the words of King Solomon:
# "Give therefore thy servant an understanding heart to judge thy people, that I may discern between good and bad; for who is able to judge this thy so great a people?"
# I ask only to be a good and faithful servant of my Lord and my people.

# %% [markdown]
# ## Part 3 – Word Tokenization

# %% [markdown]
# 📌 Tokenization splits text into meaningful units (tokens).
# There is no universal standard, but conventions vary by task and language.

# %%
from nltk.tokenize import word_tokenize
tokens_nltk = word_tokenize(raw_text)
tokens_nltk
# Out:
# ['PRESIDENT',
#  'HARRY',
#  'S.',
#  'TRUMAN',
#  "'S",
#  'ADDRESS',
#  'BEFORE',
#  'A',
#  'JOINT',
#  'SESSION',
#  'OF',
#  'THE',
#  'CONGRESS',
#  'April',
#  '16',
#  ',',
#  '1945',
#  'Mr.',
#  'Speaker',
#  ',',
#  'Mr.',
#  'President',
#  ',',
#  'Members',
#  'of',
#  'the',
#  'Congress',
#  ':',
#  'It',
#  'is',
#  'with',
#  'a',
#  'heavy',
#  'heart',
#  'that',
#  'I',
#  'stand',
#  'before',
#  'you',
#  ',',
#  'my',
#  'friends',
#  'and',
#  'colleagues',
#  ',',
#  'in',
#  'the',
#  'Congress',
#  'of',
#  'the',
#  'United',
#  'States',
#  '.',
#  'Only',
#  'yesterday',
#  ',',
#  'we',
#  'laid',
#  'to',
#  'rest',
#  'the',
#  'mortal',
#  'remains',
#  'of',
#  'our',
#  'beloved',
#  'President',
#  ',',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  '.',
#  'At',
#  'a',
#  'time',
#  'like',
#  'this',
#  ',',
#  'words',
#  'are',
#  'inadequate',
#  '.',
#  'The',
#  'most',
#  'eloquent',
#  'tribute',
#  'would',
#  'be',
#  'a',
#  'reverent',
#  'silence',
#  '.',
#  'Yet',
#  ',',
#  'in',
#  'this',
#  'decisive',
#  'hour',
#  ',',
#  'when',
#  'world',
#  'events',
#  'are',
#  'moving',
#  'so',
#  'rapidly',
#  ',',
#  'our',
#  'silence',
#  'might',
#  'be',
#  'misunderstood',
#  'and',
#  'might',
#  'give',
#  'comfort',
#  'to',
#  'our',
#  'enemies',
#  '.',
#  'In',
#  'His',
#  'infinite',
#  'wisdom',
#  ',',
#  'Almighty',
#  'God',
#  'has',
#  'seen',
#  'fit',
#  'to',
#  'take',
#  'from',
#  'us',
#  'a',
#  'great',
#  'man',
#  'who',
#  'loved',
#  ',',
#  'and',
#  'was',
#  'beloved',
#  'by',
#  ',',
#  'all',
#  'humanity',
#  '.',
#  'No',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'the',
#  'tremendous',
#  'void',
#  'left',
#  'by',
#  'the',
#  'passing',
#  'of',
#  'that',
#  'noble',
#  'soul',
#  '.',
#  'No',
#  'words',
#  'can',
#  'ease',
#  'the',
#  'aching',
#  'hearts',
#  'of',
#  'untold',
#  'millions',
#  'of',
#  'every',
#  'race',
#  ',',
#  'creed',
#  'and',
#  'color',
#  '.',
#  'The',
#  'world',
#  'knows',
#  'it',
#  'has',
#  'lost',
#  'a',
#  'heroic',
#  'champion',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  '.',
#  'Tragic',
#  'fate',
#  'has',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  '.',
#  'We',
#  'must',
#  'carry',
#  'on.Our',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  '.',
#  'He',
#  'looked',
#  'forward',
#  'and',
#  'moved',
#  'forward',
#  '.',
#  'That',
#  'is',
#  'what',
#  'he',
#  'would',
#  'want',
#  'us',
#  'to',
#  'do',
#  '.',
#  'That',
#  'is',
#  'what',
#  'America',
#  'will',
#  'do',
#  '.',
#  'So',
#  'much',
#  'blood',
#  'has',
#  'already',
#  'been',
#  'shed',
#  'for',
#  'the',
#  'ideals',
#  'which',
#  'we',
#  'cherish',
#  ',',
#  'and',
#  'for',
#  'which',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  'lived',
#  'and',
#  'died',
#  ',',
#  'that',
#  'we',
#  'dare',
#  'not',
#  'permit',
#  'even',
#  'a',
#  'momentary',
#  'pause',
#  'in',
#  'the',
#  'hard',
#  'fight',
#  'for',
#  'victory',
#  '.',
#  'Today',
#  ',',
#  'the',
#  'entire',
#  'world',
#  'is',
#  'looking',
#  'to',
#  'America',
#  'for',
#  'enlightened',
#  'leadership',
#  'to',
#  'peace',
#  'and',
#  'progress',
#  '.',
#  'Such',
#  'a',
#  'leadership',
#  'requires',
#  'vision',
#  ',',
#  'courage',
#  'and',
#  'tolerance',
#  '.',
#  'It',
#  'can',
#  'be',
#  'provided',
#  'only',
#  'by',
#  'a',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'to',
#  'the',
#  'highest',
#  'ideals',
#  '.',
#  'With',
#  'great',
#  'humility',
#  'I',
#  'call',
#  'upon',
#  'all',
#  'Americans',
#  'to',
#  'help',
#  'me',
#  'keep',
#  'our',
#  'nation',
#  'united',
#  'in',
#  'defense',
#  'of',
#  'those',
#  'ideals',
#  'which',
#  'have',
#  'been',
#  'so',
#  'eloquently',
#  'proclaimed',
#  'by',
#  'Franklin',
#  'Roosevelt',
#  '.',
#  'I',
#  'want',
#  'in',
#  'turn',
#  'to',
#  'assure',
#  'my',
#  'fellow',
#  'Americans',
#  'and',
#  'all',
#  'of',
#  'those',
#  'who',
#  'love',
#  'peace',
#  'and',
#  'liberty',
#  'throughout',
#  'the',
#  'world',
#  'that',
#  'I',
#  'will',
#  'support',
#  'and',
#  'defend',
#  'those',
#  'ideals',
#  'with',
#  'all',
#  'my',
#  'strength',
#  'and',
#  'all',
#  'my',
#  'heart',
#  '.',
#  'That',
#  'is',
#  'my',
#  'duty',
#  'and',
#  'I',
#  'shall',
#  'not',
#  'shirk',
#  'it',
#  '.',
#  'So',
#  'that',
#  'there',
#  'can',
#  'be',
#  'no',
#  'possible',
#  'misunderstanding',
#  ',',
#  'both',
#  'Germany',
#  'and',
#  'Japan',
#  'can',
#  'be',
#  'certain',
#  ',',
#  'beyond',
#  'any',
#  'shadow',
#  'of',
#  'a',
#  'doubt',
#  ',',
#  'that',
#  'America',
#  'will',
#  'continue',
#  'the',
#  'fight',
#  'for',
#  'freedom',
#  'until',
#  'no',
#  'vestige',
#  'of',
#  'resistance',
#  'remains',
#  '!',
#  'We',
#  'are',
#  'deeply',
#  'conscious',
#  'of',
#  'the',
#  'fact',
#  'that',
#  'much',
#  'hard',
#  'fighting',
#  'is',
#  'still',
#  'ahead',
#  'of',
#  'us',
#  '.',
#  'Having',
#  'to',
#  'pay',
#  'such',
#  'a',
#  'heavy',
#  'price',
#  'to',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  ',',
#  'America',
#  'will',
#  'never',
#  'become',
#  'a',
#  'party',
#  'to',
#  'any',
#  'plan',
#  'for',
#  'partial',
#  'victory',
#  '!',
#  'To',
#  'settle',
#  'for',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'the',
#  'future',
#  'security',
#  'of',
#  'all',
#  'the',
#  'world',
#  '.',
#  'Our',
#  'demand',
#  'has',
#  'been',
#  ',',
#  'and',
#  'it',
#  'remains-Unconditional',
#  'Surrender',
#  '!',
#  'We',
#  'will',
#  'not',
#  'traffic',
#  'with',
#  'the',
#  'breakers',
#  'of',
#  'the',
#  'peace',
#  'on',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'peace',
#  '.',
#  'The',
#  'responsibility',
#  'for',
#  'making',
#  'of',
#  'the',
#  'peace-and',
#  'it',
#  'is',
#  'a',
#  'very',
#  'grave',
#  'responsibility-must',
#  'rest',
#  'with',
#  'the',
#  'defenders',
#  'of',
#  'the',
#  'peace',
#  '.',
#  'We',
#  'are',
#  'not',
#  'unconscious',
#  'of',
#  'the',
#  'dictates',
#  'of',
#  'humanity',
#  '.',
#  'We',
#  'do',
#  'not',
#  'wish',
#  'to',
#  'see',
#  'unnecessary',
#  'or',
#  'unjustified',
#  'suffering',
#  '.',
#  'But',
#  'the',
#  'laws',
#  'of',
#  'Go',
#  'd',
#  'and',
#  'of',
#  'man',
#  'have',
#  'been',
#  'violated',
#  'and',
#  'the',
#  'guilty',
#  'must',
#  'not',
#  'go',
#  'unpunished',
#  '.',
#  'Nothing',
#  'shall',
#  'shake',
#  'our',
#  'determination',
#  'to',
#  'punish',
#  'the',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'we',
#  'must',
#  'pursue',
#  'them',
#  'to',
#  'the',
#  'ends',
#  'of',
#  'the',
#  'earth',
#  '.',
#  'Lasting',
#  'peace',
#  'can',
#  'never',
#  'be',
#  'secured',
#  'if',
#  'we',
#  'permit',
#  'our',
#  'dangerous',
#  'opponents',
#  'to',
#  'plot',
#  'future',
#  'wars',
#  'with',
#  'impunity',
#  'at',
#  'any',
#  'mountain',
#  'retreat',
#  '-',
#  'however',
#  'distant',
#  '.',
#  'In',
#  'this',
#  'shrinking',
#  'world',
#  ',',
#  'it',
#  'is',
#  'futile',
#  'to',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  '.',
#  'Real',
#  'security',
#  'will',
#  'be',
#  'found',
#  'only',
#  'in',
#  'law',
#  'and',
#  'in',
#  'justice',
#  '.',
#  'Here',
#  'in',
#  'America',
#  ',',
#  'we',
#  'have',
#  'labored',
#  'long',
#  'and',
#  'hard',
#  'to',
#  'achieve',
#  'a',
#  'social',
#  'order',
#  'worthy',
#  'of',
#  'our',
#  'great',
#  'heritage',
#  '.',
#  'In',
#  'our',
#  'time',
#  ',',
#  'tremendous',
#  'progress',
#  'has',
#  'been',
#  'made',
#  'toward',
#  'a',
#  'really',
#  'democratic',
#  'way',
#  'of',
#  'life',
#  '.',
#  'Let',
#  'me',
#  'assure',
#  'the',
#  'forward-looking',
#  'people',
#  'of',
#  'America',
#  'that',
#  'there',
#  'w',
#  'ill',
#  'be',
#  'no',
#  'relaxation',
#  'in',
#  'our',
#  'efforts',
#  'to',
#  'improve',
#  'the',
#  'lot',
#  'of',
#  'the',
#  'common',
#  'people',
#  '.',
#  'In',
#  'the',
#  'difficult',
#  'days',
#  'ahead',
#  ',',
#  'unquestionably',
#  'we',
#  'shall',
#  'face',
#  'problems',
#  'of',
#  'staggering',
#  'proportions',
#  '.',
#  'However',
#  ',',
#  'with',
#  'the',
#  'faith',
#  'of',
#  'our',
#  'fathers',
#  'in',
#  'our',
#  'hearts',
#  ',',
#  'we',
#  'do',
#  'not',
#  'fear',
#  'the',
#  'future',
#  '.',
#  'On',
#  'the',
#  'battlefields',
#  ',',
#  'we',
#  'have',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  '-',
#  'and',
#  'won',
#  '!',
#  'At',
#  'home',
#  ',',
#  'Americans',
#  'will',
#  'not',
#  'be',
#  'less',
#  'resolute',
#  '!',
#  'We',
#  'shall',
#  'never',
#  'cease',
#  'our',
#  'struggle',
#  'to',
#  'preserve',
#  'and',
#  'maintain',
#  'our',
#  'American',
#  'way',
#  'of',
#  'life',
#  '.',
#  'At',
#  'this',
#  'moment',
#  ',',
#  'America',
#  ',',
#  'along',
#  'with',
#  'her',
#  'brave',
#  'Allies',
#  ',',
#  'is',
#  'paying',
#  'again',
#  'a',
#  'heavy',
#  'price',
#  'for',
#  'the',
#  'defense',
#  'of',
#  'our',
#  'freedom',
#  '.',
#  'With',
#  'characteristic',
#  'energy',
#  ',',
#  'we',
#  'are',
#  'assisting',
#  'in',
#  'the',
#  'liberation',
#  'of',
#  'entire',
#  'nations',
#  '.',
#  'Gradually',
#  ',',
#  'the',
#  'shackles',
#  'of',
#  'slavery',
#  'are',
#  'being',
#  'broken',
#  'by',
#  't',
#  'he',
#  'forces',
#  'of',
#  'freedom',
#  '.',
#  'All',
#  'of',
#  'us',
#  'are',
#  'praying',
#  'for',
#  'a',
#  'speedy',
#  'victory',
#  '.',
#  'Every',
#  'day',
#  'peace',
#  'is',
#  'delayed',
#  'costs',
#  'a',
#  'terrible',
#  'toll',
#  '.',
#  'The',
#  'armies',
#  'of',
#  'liberation',
#  'today',
#  'are',
#  'bringing',
#  'to',
#  'an',
#  'end',
#  'Hitler',
#  "'s",
#  'ghastly',
#  'threat',
#  'to',
#  'dominate',
#  'the',
#  'world',
#  '.',
#  'Tokyo',
#  'rocks',
#  'under',
#  'the',
#  'weight',
#  'of',
#  'our',
#  'bombs',
#  '.',
#  'The',
#  'grand',
#  'strategy',
#  'of',
#  'the',
#  'United',
#  'Nations',
#  "'",
#  'war',
#  'has',
#  'been',
#  'determined',
#  '-',
#  'due',
#  'in',
#  'no',
#  'small',
#  'measure',
#  'to',
#  'the',
#  'vision',
#  'of',
#  'our',
#  'departed',
#  'Commander',
#  'in',
#  'Chief',
#  '.',
#  'We',
#  'are',
#  'now',
#  'carrying',
#  'out',
#  'our',
#  'part',
#  'of',
#  'that',
#  'strategy',
#  'under',
#  'the',
#  'able',
#  'direction',
#  'of',
#  'Admiral',
#  'Leahy',
#  ',',
#  'General',
#  'Marshall',
#  ',',
#  'A',
#  'dmiral',
#  'King',
#  ',',
#  'General',
#  'Arnold',
#  ',',
#  'General',
#  'Eisenhower',
#  ',',
#  'Admiral',
#  'Nimitz',
#  'and',
#  'General',
#  'MacArthur',
#  '.',
#  'I',
#  'want',
#  'the',
#  'entire',
#  'world',
#  'to',
#  'know',
#  'that',
#  'this',
#  'direction',
#  'must',
#  'and',
#  'will',
#  'remain-unchanged',
#  'and',
#  'unhampered',
#  '!',
#  'Our',
#  'debt',
#  'to',
#  'the',
#  'heroic',
#  'men',
#  'and',
#  'valiant',
#  'women',
#  ...]

# %%
from nltk.tokenize import word_tokenize
tokens_spacy = [token.text for token in doc]

tokens_spacy
# Out:
# ['PRESIDENT',
#  'HARRY',
#  'S.',
#  'TRUMAN',
#  "'S",
#  'ADDRESS',
#  'BEFORE',
#  'A',
#  'JOINT',
#  'SESSION',
#  'OF',
#  'THE',
#  'CONGRESS',
#  '\n \n',
#  'April',
#  '16',
#  ',',
#  '1945',
#  '\n\n',
#  'Mr.',
#  'Speaker',
#  ',',
#  'Mr.',
#  'President',
#  ',',
#  'Members',
#  'of',
#  'the',
#  'Congress',
#  ':',
#  '\n',
#  'It',
#  'is',
#  'with',
#  'a',
#  'heavy',
#  'heart',
#  'that',
#  'I',
#  'stand',
#  'before',
#  'you',
#  ',',
#  'my',
#  'friends',
#  'and',
#  'colleagues',
#  ',',
#  'in',
#  'the',
#  'Congress',
#  'of',
#  'the',
#  'United',
#  'States',
#  '.',
#  '\n',
#  'Only',
#  'yesterday',
#  ',',
#  'we',
#  'laid',
#  'to',
#  'rest',
#  'the',
#  'mortal',
#  'remains',
#  'of',
#  'our',
#  'beloved',
#  'President',
#  ',',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  '.',
#  'At',
#  'a',
#  'time',
#  'like',
#  'this',
#  ',',
#  'words',
#  'are',
#  'inadequate',
#  '.',
#  'The',
#  'most',
#  'eloquent',
#  'tribute',
#  'would',
#  'be',
#  'a',
#  'reverent',
#  'silence',
#  '.',
#  '\n',
#  'Yet',
#  ',',
#  'in',
#  'this',
#  'decisive',
#  'hour',
#  ',',
#  'when',
#  'world',
#  'events',
#  'are',
#  'moving',
#  'so',
#  'rapidly',
#  ',',
#  'our',
#  'silence',
#  'might',
#  'be',
#  'misunderstood',
#  'and',
#  'might',
#  'give',
#  'comfort',
#  'to',
#  'our',
#  'enemies',
#  '.',
#  '\n',
#  'In',
#  'His',
#  'infinite',
#  'wisdom',
#  ',',
#  'Almighty',
#  'God',
#  'has',
#  'seen',
#  'fit',
#  'to',
#  'take',
#  'from',
#  'us',
#  'a',
#  'great',
#  'man',
#  'who',
#  'loved',
#  ',',
#  'and',
#  'was',
#  'beloved',
#  'by',
#  ',',
#  'all',
#  'humanity',
#  '.',
#  '\n',
#  'No',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'the',
#  'tremendous',
#  'void',
#  'left',
#  'by',
#  'the',
#  'passing',
#  'of',
#  'that',
#  'noble',
#  'soul',
#  '.',
#  'No',
#  'words',
#  'can',
#  'ease',
#  'the',
#  'aching',
#  'hearts',
#  'of',
#  'untold',
#  'millions',
#  'of',
#  'every',
#  'race',
#  ',',
#  'creed',
#  'and',
#  'color',
#  '.',
#  'The',
#  'world',
#  'knows',
#  'it',
#  'has',
#  'lost',
#  'a',
#  'heroic',
#  'champion',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  '.',
#  '\n',
#  'Tragic',
#  'fate',
#  'has',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  '.',
#  'We',
#  'must',
#  'carry',
#  'on',
#  '.',
#  'Our',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  '.',
#  'He',
#  'looked',
#  'forward',
#  'and',
#  'moved',
#  'forward',
#  '.',
#  'That',
#  'is',
#  'what',
#  'he',
#  'would',
#  'want',
#  'us',
#  'to',
#  'do',
#  '.',
#  'That',
#  'is',
#  'what',
#  'America',
#  'will',
#  'do',
#  '.',
#  '\n',
#  'So',
#  'much',
#  'blood',
#  'has',
#  'already',
#  'been',
#  'shed',
#  'for',
#  'the',
#  'ideals',
#  'which',
#  'we',
#  'cherish',
#  ',',
#  'and',
#  'for',
#  'which',
#  'Franklin',
#  'Delano',
#  'Roosevelt',
#  'lived',
#  'and',
#  'died',
#  ',',
#  'that',
#  'we',
#  'dare',
#  'not',
#  'permit',
#  'even',
#  'a',
#  'momentary',
#  'pause',
#  'in',
#  'the',
#  'hard',
#  'fight',
#  'for',
#  'victory',
#  '.',
#  '\n',
#  'Today',
#  ',',
#  'the',
#  'entire',
#  'world',
#  'is',
#  'looking',
#  'to',
#  'America',
#  'for',
#  'enlightened',
#  'leadership',
#  'to',
#  'peace',
#  'and',
#  'progress',
#  '.',
#  'Such',
#  'a',
#  'leadership',
#  'requires',
#  'vision',
#  ',',
#  'courage',
#  'and',
#  'tolerance',
#  '.',
#  'It',
#  'can',
#  'be',
#  'provided',
#  'only',
#  'by',
#  'a',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'to',
#  'the',
#  'highest',
#  'ideals',
#  '.',
#  '\n',
#  'With',
#  'great',
#  'humility',
#  'I',
#  'call',
#  'upon',
#  'all',
#  'Americans',
#  'to',
#  'help',
#  'me',
#  'keep',
#  'our',
#  'nation',
#  'united',
#  'in',
#  'defense',
#  'of',
#  'those',
#  'ideals',
#  'which',
#  'have',
#  'been',
#  'so',
#  'eloquently',
#  'proclaimed',
#  'by',
#  'Franklin',
#  'Roosevelt',
#  '.',
#  '\n',
#  'I',
#  'want',
#  'in',
#  'turn',
#  'to',
#  'assure',
#  'my',
#  'fellow',
#  'Americans',
#  'and',
#  'all',
#  'of',
#  'those',
#  'who',
#  'love',
#  'peace',
#  'and',
#  'liberty',
#  'throughout',
#  'the',
#  'world',
#  'that',
#  'I',
#  'will',
#  'support',
#  'and',
#  'defend',
#  'those',
#  'ideals',
#  'with',
#  'all',
#  'my',
#  'strength',
#  'and',
#  'all',
#  'my',
#  'heart',
#  '.',
#  'That',
#  'is',
#  'my',
#  'duty',
#  'and',
#  'I',
#  'shall',
#  'not',
#  'shirk',
#  'it',
#  '.',
#  '\n',
#  'So',
#  'that',
#  'there',
#  'can',
#  'be',
#  'no',
#  'possible',
#  'misunderstanding',
#  ',',
#  'both',
#  'Germany',
#  'and',
#  'Japan',
#  'can',
#  'be',
#  'certain',
#  ',',
#  'beyond',
#  'any',
#  'shadow',
#  'of',
#  'a',
#  'doubt',
#  ',',
#  'that',
#  'America',
#  'will',
#  'continue',
#  'the',
#  'fight',
#  'for',
#  'freedom',
#  'until',
#  'no',
#  'vestige',
#  'of',
#  'resistance',
#  'remains',
#  '!',
#  '\n',
#  'We',
#  'are',
#  'deeply',
#  'conscious',
#  'of',
#  'the',
#  'fact',
#  'that',
#  'much',
#  'hard',
#  'fighting',
#  'is',
#  'still',
#  'ahead',
#  'of',
#  'us',
#  '.',
#  '\n',
#  'Having',
#  'to',
#  'pay',
#  'such',
#  'a',
#  'heavy',
#  'price',
#  'to',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  ',',
#  'America',
#  'will',
#  'never',
#  'become',
#  'a',
#  'party',
#  'to',
#  'any',
#  'plan',
#  'for',
#  'partial',
#  'victory',
#  '!',
#  '\n',
#  'To',
#  'settle',
#  'for',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'the',
#  'future',
#  'security',
#  'of',
#  'all',
#  'the',
#  'world',
#  '.',
#  '\n',
#  'Our',
#  'demand',
#  'has',
#  'been',
#  ',',
#  'and',
#  'it',
#  'remains',
#  '-',
#  'Unconditional',
#  'Surrender',
#  '!',
#  'We',
#  'will',
#  'not',
#  'traffic',
#  'with',
#  'the',
#  'breakers',
#  'of',
#  'the',
#  'peace',
#  'on',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'peace',
#  '.',
#  '\n',
#  'The',
#  'responsibility',
#  'for',
#  'making',
#  'of',
#  'the',
#  'peace',
#  '-',
#  'and',
#  'it',
#  'is',
#  'a',
#  'very',
#  'grave',
#  'responsibility',
#  '-',
#  'must',
#  'rest',
#  'with',
#  'the',
#  'defenders',
#  'of',
#  'the',
#  'peace',
#  '.',
#  'We',
#  'are',
#  'not',
#  'unconscious',
#  'of',
#  'the',
#  'dictates',
#  'of',
#  'humanity',
#  '.',
#  'We',
#  'do',
#  'not',
#  'wish',
#  'to',
#  'see',
#  'unnecessary',
#  'or',
#  'unjustified',
#  'suffering',
#  '.',
#  'But',
#  'the',
#  'laws',
#  'of',
#  'Go',
#  'd',
#  'and',
#  'of',
#  'man',
#  'have',
#  'been',
#  'violated',
#  'and',
#  'the',
#  'guilty',
#  'must',
#  'not',
#  'go',
#  'unpunished',
#  '.',
#  'Nothing',
#  'shall',
#  'shake',
#  'our',
#  'determination',
#  'to',
#  'punish',
#  'the',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'we',
#  'must',
#  'pursue',
#  'them',
#  'to',
#  'the',
#  'ends',
#  'of',
#  'the',
#  'earth',
#  '.',
#  '\n',
#  'Lasting',
#  'peace',
#  'can',
#  'never',
#  'be',
#  'secured',
#  'if',
#  'we',
#  'permit',
#  'our',
#  'dangerous',
#  'opponents',
#  'to',
#  'plot',
#  'future',
#  'wars',
#  'with',
#  'impunity',
#  'at',
#  'any',
#  'mountain',
#  'retreat',
#  '-',
#  'however',
#  'distant',
#  '.',
#  '\n',
#  'In',
#  'this',
#  'shrinking',
#  'world',
#  ',',
#  'it',
#  'is',
#  'futile',
#  'to',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  '.',
#  'Real',
#  'security',
#  'will',
#  'be',
#  'found',
#  'only',
#  'in',
#  'law',
#  'and',
#  'in',
#  'justice',
#  '.',
#  '\n',
#  'Here',
#  'in',
#  'America',
#  ',',
#  'we',
#  'have',
#  'labored',
#  'long',
#  'and',
#  'hard',
#  'to',
#  'achieve',
#  'a',
#  'social',
#  'order',
#  'worthy',
#  'of',
#  'our',
#  'great',
#  'heritage',
#  '.',
#  'In',
#  'our',
#  'time',
#  ',',
#  'tremendous',
#  'progress',
#  'has',
#  'been',
#  'made',
#  'toward',
#  'a',
#  'really',
#  'democratic',
#  'way',
#  'of',
#  'life',
#  '.',
#  'Let',
#  'me',
#  'assure',
#  'the',
#  'forward',
#  '-',
#  'looking',
#  'people',
#  'of',
#  'America',
#  'that',
#  'there',
#  'w',
#  'ill',
#  'be',
#  'no',
#  'relaxation',
#  'in',
#  'our',
#  'efforts',
#  'to',
#  'improve',
#  'the',
#  'lot',
#  'of',
#  'the',
#  'common',
#  'people',
#  '.',
#  '\n',
#  'In',
#  'the',
#  'difficult',
#  'days',
#  'ahead',
#  ',',
#  'unquestionably',
#  'we',
#  'shall',
#  'face',
#  'problems',
#  'of',
#  'staggering',
#  'proportions',
#  '.',
#  'However',
#  ',',
#  'with',
#  'the',
#  'faith',
#  'of',
#  'our',
#  'fathers',
#  'in',
#  'our',
#  'hearts',
#  ',',
#  'we',
#  'do',
#  'not',
#  'fear',
#  'the',
#  'future',
#  '.',
#  '\n',
#  'On',
#  'the',
#  'battlefields',
#  ',',
#  'we',
#  'have',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  '-',
#  'and',
#  'won',
#  '!',
#  'At',
#  'home',
#  ',',
#  'Americans',
#  'will',
#  'not',
#  'be',
#  'less',
#  'resolute',
#  '!',
#  'We',
#  'shall',
#  'never',
#  'cease',
#  'our',
#  'struggle',
#  'to',
#  'preserve',
#  'and',
#  'maintain',
#  'our',
#  'American',
#  'way',
#  'of',
#  'life',
#  '.',
#  '\n',
#  'At',
#  'this',
#  'moment',
#  ',',
#  'America',
#  ',',
#  'along',
#  'with',
#  'her',
#  'brave',
#  'Allies',
#  ',',
#  'is',
#  'paying',
#  'again',
#  'a',
#  'heavy',
#  'price',
#  'for',
#  'the',
#  'defense',
#  'of',
#  'our',
#  'freedom',
#  '.',
#  'With',
#  'characteristic',
#  'energy',
#  ',',
#  'we',
#  'are',
#  'assisting',
#  'in',
#  'the',
#  'liberation',
#  'of',
#  'entire',
#  'nations',
#  '.',
#  'Gradually',
#  ',',
#  'the',
#  'shackles',
#  'of',
#  'slavery',
#  'are',
#  'being',
#  'broken',
#  'by',
#  't',
#  'he',
#  'forces',
#  'of',
#  'freedom',
#  '.',
#  '\n',
#  'All',
#  'of',
#  'us',
#  'are',
#  'praying',
#  'for',
#  'a',
#  'speedy',
#  'victory',
#  '.',
#  'Every',
#  'day',
#  'peace',
#  'is',
#  'delayed',
#  'costs',
#  'a',
#  'terrible',
#  'toll',
#  '.',
#  '\n',
#  'The',
#  'armies',
#  'of',
#  'liberation',
#  'today',
#  'are',
#  'bringing',
#  'to',
#  'an',
#  'end',
#  'Hitler',
#  "'s",
#  'ghastly',
#  'threat',
#  'to',
#  'dominate',
#  'the',
#  'world',
#  '.',
#  'Tokyo',
#  'rocks',
#  'under',
#  'the',
#  'weight',
#  'of',
#  'our',
#  'bombs',
#  '.',
#  '\n',
#  'The',
#  'grand',
#  'strategy',
#  'of',
#  'the',
#  'United',
#  'Nations',
#  "'",
#  'war',
#  'has',
#  'been',
#  'determined',
#  '-',
#  'due',
#  'in',
#  'no',
#  'small',
#  'measure',
#  'to',
#  'the',
#  'vision',
#  'of',
#  'our',
#  'departed',
#  'Commander',
#  'in',
#  'Chief',
#  '.',
#  'We',
#  'are',
#  'now',
#  'carrying',
#  'out',
#  'our',
#  'part',
#  'of',
#  'that',
#  'strategy',
#  'under',
#  'the',
#  'able',
#  'direction',
#  'of',
#  'Admiral',
#  'Leahy',
#  ',',
#  'General',
#  'Marshall',
#  ',',
#  'A',
#  'dmiral',
#  'King',
#  ',',
#  'General',
#  ...]

# %% [markdown]
# ## Part 4 – Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize
sent_tokens_nltk = sent_tokenize(raw_text)
sent_tokens_nltk
# Out:
# ["PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS\n \nApril 16, 1945\n\nMr. Speaker, Mr. President, Members of the Congress:\nIt is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.",
#  'Only yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt.',
#  'At a time like this, words are inadequate.',
#  'The most eloquent tribute would be a reverent silence.',
#  'Yet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.',
#  'In His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.',
#  'No man could possibly fill the tremendous void left by the passing of that noble soul.',
#  'No words can ease the aching hearts of untold millions of every race, creed and color.',
#  'The world knows it has lost a heroic champion of justice and freedom.',
#  'Tragic fate has thrust upon us grave responsibilities.',
#  'We must carry on.Our departed leader never looked backward.',
#  'He looked forward and moved forward.',
#  'That is what he would want us to do.',
#  'That is what America will do.',
#  'So much blood has already been shed for the ideals which we cherish, and for which Franklin Delano Roosevelt lived and died, that we dare not permit even a momentary pause in the hard fight for victory.',
#  'Today, the entire world is looking to America for enlightened leadership to peace and progress.',
#  'Such a leadership requires vision, courage and tolerance.',
#  'It can be provided only by a united nation deeply devoted to the highest ideals.',
#  'With great humility I call upon all Americans to help me keep our nation united in defense of those ideals which have been so eloquently proclaimed by Franklin Roosevelt.',
#  'I want in turn to assure my fellow Americans and all of those who love peace and liberty throughout the world that I will support and defend those ideals with all my strength and all my heart.',
#  'That is my duty and I shall not shirk it.',
#  'So that there can be no possible misunderstanding, both Germany and Japan can be certain, beyond any shadow of a doubt, that America will continue the fight for freedom until no vestige of resistance remains!',
#  'We are deeply conscious of the fact that much hard fighting is still ahead of us.',
#  'Having to pay such a heavy price to make complete victory certain, America will never become a party to any plan for partial victory!',
#  'To settle for merely another temporary respite would surely jeopardize the future security of all the world.',
#  'Our demand has been, and it remains-Unconditional Surrender!',
#  'We will not traffic with the breakers of the peace on the terms of the peace.',
#  'The responsibility for making of the peace-and it is a very grave responsibility-must rest with the defenders of the peace.',
#  'We are not unconscious of the dictates of humanity.',
#  'We do not wish to see unnecessary or unjustified suffering.',
#  'But the laws of Go d and of man have been violated and the guilty must not go unpunished.',
#  'Nothing shall shake our determination to punish the war criminals even though we must pursue them to the ends of the earth.',
#  'Lasting peace can never be secured if we permit our dangerous opponents to plot future wars with impunity at any mountain retreat - however distant.',
#  'In this shrinking world, it is futile to seek safety behind geographical barriers.',
#  'Real security will be found only in law and in justice.',
#  'Here in America, we have labored long and hard to achieve a social order worthy of our great heritage.',
#  'In our time, tremendous progress has been made toward a really democratic way of life.',
#  'Let me assure the forward-looking people of America that there w ill be no relaxation in our efforts to improve the lot of the common people.',
#  'In the difficult days ahead, unquestionably we shall face problems of staggering proportions.',
#  'However, with the faith of our fathers in our hearts, we do not fear the future.',
#  'On the battlefields, we have frequently faced overwhelming odds - and won!',
#  'At home, Americans will not be less resolute!',
#  'We shall never cease our struggle to preserve and maintain our American way of life.',
#  'At this moment, America, along with her brave Allies, is paying again a heavy price for the defense of our freedom.',
#  'With characteristic energy, we are assisting in the liberation of entire nations.',
#  'Gradually, the shackles of slavery are being broken by t he forces of freedom.',
#  'All of us are praying for a speedy victory.',
#  'Every day peace is delayed costs a terrible toll.',
#  "The armies of liberation today are bringing to an end Hitler's ghastly threat to dominate the world.",
#  'Tokyo rocks under the weight of our bombs.',
#  "The grand strategy of the United Nations' war has been determined - due in no small measure to the vision of our departed Commander in Chief.",
#  'We are now carrying out our part of that strategy under the able direction of Admiral Leahy, General Marshall, A dmiral King, General Arnold, General Eisenhower, Admiral Nimitz and General MacArthur.',
#  'I want the entire world to know that this direction must and will remain-unchanged and unhampered!',
#  'Our debt to the heroic men and valiant women in the service of our country can never be repaid.',
#  'They have earned our undying gratitude.',
#  'America will never forget their sacrifices.',
#  'Because of these sacrifices, the dawn of justice and freedom throughout th e world slowly casts its gleam across the horizon.',
#  'Our forefathers came to our rugged shores in search of religious tolerance, political freedom and economic opportunity.',
#  'For those fundamental rights, they risked their lives.',
#  'We well know today that such rights can be preserved only by constant vigilance , the eternal price of liberty!',
#  'Within an hour after I took the oath of office, I announced that the San Francisco Conference would proceed.',
#  'We will face the problems of peace with the same courage that we have faced and mastered the problems of war.',
#  'In the memory of those who have made the supreme sacrifice-in the memory of our fallen President-we shall not fail!',
#  'It is not enough to yearn for peace.',
#  'We must work, and if necessary, fight for it.',
#  'The task of creating a sound international organization is complicated and difficult.',
#  'Yet, without such organization, the rights of man on earth cannot be protected.',
#  'Machi nery for the just settlement of international differences must be found.',
#  'Without such machinery, the entire world will have to remain an armed camp.',
#  'The world will be doomed to deadly conflict, devoid of hope for real peace.',
#  'Fortunately, people have retained hope for a durable peace.',
#  'Thoughtful people have always had faith that ultimately justice must triumph.',
#  'Past experience surely indicates that, without justice, an enduring peace becomes impossible.',
#  'In bitter despair, some people have come to believe that wars are inevitable.',
#  'With tragic fatalism, they insist that wars have always been, of necessity, and of necessity wars always will be.',
#  'To such defeatism, men and women of good will must not and can not yield.',
#  'The outlook for humanity is not so hopeless.',
#  'During the dark hours of this horrible war, entire nations were kept going by something intangible-hope!',
#  'When warned that abject submission offered the only salvation against overwhelming power, hope showed the way to victory.',
#  'Hope has become the secret weapon of the forces of liberation!',
#  'Aggressors could not dominate the human mind.',
#  'As long as hope remains, the spirit of man will never be crushed.',
#  'But hope alone was not and is not sufficient to avert war.',
#  'We must not only have hope but we must have faith enough to work with other peace-loving nations to maintain the peace.',
#  "Hope was not enough to beat back the aggressors as long as the peace-loving nations were unwilling to come to each other's defense.",
#  'The aggressors were beaten back only when the peace-loving nations united to defend themselves.',
#  'If wars in the future are to be prevented the nations must be united in their determination to keep the peace under law.',
#  'Nothing is more essential to the future peace of the world than continued cooperation of the nations which had to muster the force necessary to defeat the conspiracy of the Axis powers to dominate the world.',
#  'While these great states have a special responsibility to enforce the peace, their responsibility is based upon the obligations resting upon all states, large and small, not to use force in international relations except in the defense of law.',
#  'The respon sibility of the great states is to serve and not to dominate the world.',
#  'To build a foundation of enduring peace we must not only work in harmony with our friends abroad, but we must have the united support of our own people.',
#  'Even the most experienced pilot cannot bring a ship safely into harbor, unless he has the full cooperation of the crew.',
#  'For the benefit of all, every individual must do his duty.',
#  'I appeal to every American, regardless of party, race, creed, or color, to support our efforts to build a strong and lasting United Nations Organization.',
#  'You, the Members of the Congress, surely know how I feel.',
#  'Only with your help can I hope to complete one of the greatest tasks ever assigned to a public servant.',
#  'With Divine guidance, and your help, we will find the new passage to a far better world, a kindly and friendly world, with just and lasting peace.',
#  'With confidence, I am depending upon all of you.',
#  'To destroy greedy tyrants with dreams of world domination, we cannot continue in successive generations to sacrifice our finest youth.',
#  'In the name of human decency and civilization, a more rational method of deciding national differences must and will be found!',
#  'America must assist suffering humanity back along the path of peaceful progress.',
#  'This will require time and tolerance.',
#  'We shall need also an abiding faith in the people, the kind of faith and courage which Franklin Delano Roosevelt always had!',
#  'Today, America has become one of the most powerful forces for good on earth.',
#  'We must keep it so.',
#  'We have achieved a world leadership which does not depend solely upon our military and naval might.',
#  'We have learned to fight with other nations in common defense of our freedom.',
#  'We must now learn to live with other nations for our mutual good.',
#  'We must learn to trade more with other nations so that there may be-for our mutual advantage-increased product ion, increased employment and better standards of living throughout the world.',
#  'May we Americans all live up to our glorious heritage.',
#  'In that way, America may well lead the world to peace and prosperity.',
#  'At this moment, I have in my heart a prayer.',
#  'As I have assumed my heavy duties, I humbly pray Almighty God, in the words of King Solomon:\n"Give therefore thy servant an understanding heart to judge thy people, that I may discern between good and bad; for who is able to judge this thy so great a people?"',
#  'I ask only to be a good and faithful servant of my Lord and my people.']

# %%
sentences_spacy = list(doc.sents)
sentences_spacy
# Out:
# [PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS
#
#  April 16, 1945
#
#  Mr. Speaker, Mr. President, Members of the Congress:,
#  It is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.,
#  Only yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt.,
#  At a time like this, words are inadequate.,
#  The most eloquent tribute would be a reverent silence.,
#  Yet, in this decisive hour, when world events are moving so rapidly, our silence might be misunderstood and might give comfort to our enemies.,
#  In His infinite wisdom, Almighty God has seen fit to take from us a great man who loved, and was beloved by, all humanity.,
#  No man could possibly fill the tremendous void left by the passing of that noble soul.,
#  No words can ease the aching hearts of untold millions of every race, creed and color.,
#  The world knows it has lost a heroic champion of justice and freedom.,
#  Tragic fate has thrust upon us grave responsibilities.,
#  We must carry on.,
#  Our departed leader never looked backward.,
#  He looked forward and moved forward.,
#  That is what he would want us to do.,
#  That is what America will do.,
#  So much blood has already been shed for the ideals which we cherish, and for which Franklin Delano Roosevelt lived and died, that we dare not permit even a momentary pause in the hard fight for victory.,
#  Today, the entire world is looking to America for enlightened leadership to peace and progress.,
#  Such a leadership requires vision, courage and tolerance.,
#  It can be provided only by a united nation deeply devoted to the highest ideals.,
#  With great humility I call upon all Americans to help me keep our nation united in defense of those ideals which have been so eloquently proclaimed by Franklin Roosevelt.,
#  I want in turn to assure my fellow Americans and all of those who love peace and liberty throughout the world that I will support and defend those ideals with all my strength and all my heart.,
#  That is my duty and I shall not shirk it.,
#  So that there can be no possible misunderstanding, both Germany and Japan can be certain, beyond any shadow of a doubt, that America will continue the fight for freedom until no vestige of resistance remains!,
#  We are deeply conscious of the fact that much hard fighting is still ahead of us.,
#  Having to pay such a heavy price to make complete victory certain, America will never become a party to any plan for partial victory!,
#  To settle for merely another temporary respite would surely jeopardize the future security of all the world.,
#  Our demand has been, and it remains-Unconditional Surrender!,
#  We will not traffic with the breakers of the peace on the terms of the peace.,
#  The responsibility for making of the peace-and it is a very grave responsibility-must rest with the defenders of the peace.,
#  We are not unconscious of the dictates of humanity.,
#  We do not wish to see unnecessary or unjustified suffering.,
#  But the laws of Go d and of man have been violated and the guilty must not go unpunished.,
#  Nothing shall shake our determination to punish the war criminals even though we must pursue them to the ends of the earth.,
#  Lasting peace can never be secured if we permit our dangerous opponents to plot future wars with impunity at any mountain retreat - however distant.,
#  In this shrinking world, it is futile to seek safety behind geographical barriers.,
#  Real security will be found only in law and in justice.,
#  Here in America, we have labored long and hard to achieve a social order worthy of our great heritage.,
#  In our time, tremendous progress has been made toward a really democratic way of life.,
#  Let me assure the forward-looking people of America that there w ill be no relaxation in our efforts to improve the lot of the common people.,
#  In the difficult days ahead, unquestionably we shall face problems of staggering proportions.,
#  However, with the faith of our fathers in our hearts, we do not fear the future.,
#  On the battlefields, we have frequently faced overwhelming odds - and won!,
#  At home, Americans will not be less resolute!,
#  We shall never cease our struggle to preserve and maintain our American way of life.,
#  At this moment, America, along with her brave Allies, is paying again a heavy price for the defense of our freedom.,
#  With characteristic energy, we are assisting in the liberation of entire nations.,
#  Gradually, the shackles of slavery are being broken by t he forces of freedom.,
#  All of us are praying for a speedy victory.,
#  Every day peace is delayed costs a terrible toll.,
#  The armies of liberation today are bringing to an end Hitler's ghastly threat to dominate the world.,
#  Tokyo rocks under the weight of our bombs.,
#  The grand strategy of the United Nations' war has been determined - due in no small measure to the vision of our departed Commander in Chief.,
#  We are now carrying out our part of that strategy under the able direction of Admiral Leahy, General Marshall, A dmiral King, General Arnold, General Eisenhower, Admiral Nimitz and General MacArthur.,
#  I want the entire world to know that this direction must and will remain-unchanged and unhampered!,
#  Our debt to the heroic men and valiant women in the service of our country can never be repaid.,
#  They have earned our undying gratitude.,
#  America will never forget their sacrifices.,
#  Because of these sacrifices, the dawn of justice and freedom throughout th e world slowly casts its gleam across the horizon.,
#  Our forefathers came to our rugged shores in search of religious tolerance, political freedom and economic opportunity.,
#  For those fundamental rights, they risked their lives.,
#  We well know today that such rights can be preserved only by constant vigilance , the eternal price of liberty!,
#  Within an hour after I took the oath of office, I announced that the San Francisco Conference would proceed.,
#  We will face the problems of peace with the same courage that we have faced and mastered the problems of war.,
#  In the memory of those who have made the supreme sacrifice-in the memory of our fallen President-we shall not fail!,
#  It is not enough to yearn for peace.,
#  We must work, and if necessary, fight for it.,
#  The task of creating a sound international organization is complicated and difficult.,
#  Yet, without such organization, the rights of man on earth cannot be protected.,
#  Machi nery for the just settlement of international differences must be found.,
#  Without such machinery, the entire world will have to remain an armed camp.,
#  The world will be doomed to deadly conflict, devoid of hope for real peace.,
#  Fortunately, people have retained hope for a durable peace.,
#  Thoughtful people have always had faith that ultimately justice must triumph.,
#  Past experience surely indicates that, without justice, an enduring peace becomes impossible.,
#  In bitter despair, some people have come to believe that wars are inevitable.,
#  With tragic fatalism, they insist that wars have always been, of necessity, and of necessity wars always will be.,
#  To such defeatism, men and women of good will must not and can not yield.,
#  The outlook for humanity is not so hopeless.,
#  During the dark hours of this horrible war, entire nations were kept going by something intangible-hope!,
#  When warned that abject submission offered the only salvation against overwhelming power, hope showed the way to victory.,
#  Hope has become the secret weapon of the forces of liberation!,
#  Aggressors could not dominate the human mind.,
#  As long as hope remains, the spirit of man will never be crushed.,
#  But hope alone was not and is not sufficient to avert war.,
#  We must not only have hope but we must have faith enough to work with other peace-loving nations to maintain the peace.,
#  Hope was not enough to beat back the aggressors as long as the peace-loving nations were unwilling to come to each other's defense.,
#  The aggressors were beaten back only when the peace-loving nations united to defend themselves.,
#  If wars in the future are to be prevented the nations must be united in their determination to keep the peace under law.,
#  Nothing is more essential to the future peace of the world than continued cooperation of the nations which had to muster the force necessary to defeat the conspiracy of the Axis powers to dominate the world.,
#  While these great states have a special responsibility to enforce the peace, their responsibility is based upon the obligations resting upon all states, large and small, not to use force in international relations except in the defense of law.,
#  The respon sibility of the great states is to serve and not to dominate the world.,
#  To build a foundation of enduring peace we must not only work in harmony with our friends abroad, but we must have the united support of our own people.,
#  Even the most experienced pilot cannot bring a ship safely into harbor, unless he has the full cooperation of the crew.,
#  For the benefit of all, every individual must do his duty.,
#  I appeal to every American, regardless of party, race, creed, or color, to support our efforts to build a strong and lasting United Nations Organization.,
#  You, the Members of the Congress, surely know how I feel.,
#  Only with your help can I hope to complete one of the greatest tasks ever assigned to a public servant.,
#  With Divine guidance, and your help, we will find the new passage to a far better world, a kindly and friendly world, with just and lasting peace.,
#  With confidence, I am depending upon all of you.,
#  To destroy greedy tyrants with dreams of world domination, we cannot continue in successive generations to sacrifice our finest youth.,
#  In the name of human decency and civilization, a more rational method of deciding national differences must and will be found!,
#  America must assist suffering humanity back along the path of peaceful progress.,
#  This will require time and tolerance.,
#  We shall need also an abiding faith in the people, the kind of faith and courage which Franklin Delano Roosevelt always had!,
#  Today, America has become one of the most powerful forces for good on earth.,
#  We must keep it so.,
#  We have achieved a world leadership which does not depend solely upon our military and naval might.,
#  We have learned to fight with other nations in common defense of our freedom.,
#  We must now learn to live with other nations for our mutual good.,
#  We must learn to trade more with other nations so that there may be-for our mutual advantage-increased product ion, increased employment and better standards of living throughout the world.,
#  May we Americans all live up to our glorious heritage.,
#  In that way, America may well lead the world to peace and prosperity.,
#  At this moment, I have in my heart a prayer.,
#  As I have assumed my heavy duties, I humbly pray Almighty God, in the words of King Solomon:
#  "Give therefore thy servant an understanding heart to judge thy people, that I may discern between good and bad; for who is able to judge this thy so great a people?,
#  "
#  I ask only to be a good and faithful servant of my Lord and my people.]

# %% [markdown]
# ## Part 5 – Normalization
# Normalization makes text more consistent.

# %%
normlized_nltk = [t.lower() for t in tokens_nltk if t.isalpha()]
normlized_nltk
# Out:
# ['president',
#  'harry',
#  'truman',
#  'address',
#  'before',
#  'a',
#  'joint',
#  'session',
#  'of',
#  'the',
#  'congress',
#  'april',
#  'speaker',
#  'president',
#  'members',
#  'of',
#  'the',
#  'congress',
#  'it',
#  'is',
#  'with',
#  'a',
#  'heavy',
#  'heart',
#  'that',
#  'i',
#  'stand',
#  'before',
#  'you',
#  'my',
#  'friends',
#  'and',
#  'colleagues',
#  'in',
#  'the',
#  'congress',
#  'of',
#  'the',
#  'united',
#  'states',
#  'only',
#  'yesterday',
#  'we',
#  'laid',
#  'to',
#  'rest',
#  'the',
#  'mortal',
#  'remains',
#  'of',
#  'our',
#  'beloved',
#  'president',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'at',
#  'a',
#  'time',
#  'like',
#  'this',
#  'words',
#  'are',
#  'inadequate',
#  'the',
#  'most',
#  'eloquent',
#  'tribute',
#  'would',
#  'be',
#  'a',
#  'reverent',
#  'silence',
#  'yet',
#  'in',
#  'this',
#  'decisive',
#  'hour',
#  'when',
#  'world',
#  'events',
#  'are',
#  'moving',
#  'so',
#  'rapidly',
#  'our',
#  'silence',
#  'might',
#  'be',
#  'misunderstood',
#  'and',
#  'might',
#  'give',
#  'comfort',
#  'to',
#  'our',
#  'enemies',
#  'in',
#  'his',
#  'infinite',
#  'wisdom',
#  'almighty',
#  'god',
#  'has',
#  'seen',
#  'fit',
#  'to',
#  'take',
#  'from',
#  'us',
#  'a',
#  'great',
#  'man',
#  'who',
#  'loved',
#  'and',
#  'was',
#  'beloved',
#  'by',
#  'all',
#  'humanity',
#  'no',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'the',
#  'tremendous',
#  'void',
#  'left',
#  'by',
#  'the',
#  'passing',
#  'of',
#  'that',
#  'noble',
#  'soul',
#  'no',
#  'words',
#  'can',
#  'ease',
#  'the',
#  'aching',
#  'hearts',
#  'of',
#  'untold',
#  'millions',
#  'of',
#  'every',
#  'race',
#  'creed',
#  'and',
#  'color',
#  'the',
#  'world',
#  'knows',
#  'it',
#  'has',
#  'lost',
#  'a',
#  'heroic',
#  'champion',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  'tragic',
#  'fate',
#  'has',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  'we',
#  'must',
#  'carry',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  'he',
#  'looked',
#  'forward',
#  'and',
#  'moved',
#  'forward',
#  'that',
#  'is',
#  'what',
#  'he',
#  'would',
#  'want',
#  'us',
#  'to',
#  'do',
#  'that',
#  'is',
#  'what',
#  'america',
#  'will',
#  'do',
#  'so',
#  'much',
#  'blood',
#  'has',
#  'already',
#  'been',
#  'shed',
#  'for',
#  'the',
#  'ideals',
#  'which',
#  'we',
#  'cherish',
#  'and',
#  'for',
#  'which',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'lived',
#  'and',
#  'died',
#  'that',
#  'we',
#  'dare',
#  'not',
#  'permit',
#  'even',
#  'a',
#  'momentary',
#  'pause',
#  'in',
#  'the',
#  'hard',
#  'fight',
#  'for',
#  'victory',
#  'today',
#  'the',
#  'entire',
#  'world',
#  'is',
#  'looking',
#  'to',
#  'america',
#  'for',
#  'enlightened',
#  'leadership',
#  'to',
#  'peace',
#  'and',
#  'progress',
#  'such',
#  'a',
#  'leadership',
#  'requires',
#  'vision',
#  'courage',
#  'and',
#  'tolerance',
#  'it',
#  'can',
#  'be',
#  'provided',
#  'only',
#  'by',
#  'a',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'to',
#  'the',
#  'highest',
#  'ideals',
#  'with',
#  'great',
#  'humility',
#  'i',
#  'call',
#  'upon',
#  'all',
#  'americans',
#  'to',
#  'help',
#  'me',
#  'keep',
#  'our',
#  'nation',
#  'united',
#  'in',
#  'defense',
#  'of',
#  'those',
#  'ideals',
#  'which',
#  'have',
#  'been',
#  'so',
#  'eloquently',
#  'proclaimed',
#  'by',
#  'franklin',
#  'roosevelt',
#  'i',
#  'want',
#  'in',
#  'turn',
#  'to',
#  'assure',
#  'my',
#  'fellow',
#  'americans',
#  'and',
#  'all',
#  'of',
#  'those',
#  'who',
#  'love',
#  'peace',
#  'and',
#  'liberty',
#  'throughout',
#  'the',
#  'world',
#  'that',
#  'i',
#  'will',
#  'support',
#  'and',
#  'defend',
#  'those',
#  'ideals',
#  'with',
#  'all',
#  'my',
#  'strength',
#  'and',
#  'all',
#  'my',
#  'heart',
#  'that',
#  'is',
#  'my',
#  'duty',
#  'and',
#  'i',
#  'shall',
#  'not',
#  'shirk',
#  'it',
#  'so',
#  'that',
#  'there',
#  'can',
#  'be',
#  'no',
#  'possible',
#  'misunderstanding',
#  'both',
#  'germany',
#  'and',
#  'japan',
#  'can',
#  'be',
#  'certain',
#  'beyond',
#  'any',
#  'shadow',
#  'of',
#  'a',
#  'doubt',
#  'that',
#  'america',
#  'will',
#  'continue',
#  'the',
#  'fight',
#  'for',
#  'freedom',
#  'until',
#  'no',
#  'vestige',
#  'of',
#  'resistance',
#  'remains',
#  'we',
#  'are',
#  'deeply',
#  'conscious',
#  'of',
#  'the',
#  'fact',
#  'that',
#  'much',
#  'hard',
#  'fighting',
#  'is',
#  'still',
#  'ahead',
#  'of',
#  'us',
#  'having',
#  'to',
#  'pay',
#  'such',
#  'a',
#  'heavy',
#  'price',
#  'to',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  'america',
#  'will',
#  'never',
#  'become',
#  'a',
#  'party',
#  'to',
#  'any',
#  'plan',
#  'for',
#  'partial',
#  'victory',
#  'to',
#  'settle',
#  'for',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'the',
#  'future',
#  'security',
#  'of',
#  'all',
#  'the',
#  'world',
#  'our',
#  'demand',
#  'has',
#  'been',
#  'and',
#  'it',
#  'surrender',
#  'we',
#  'will',
#  'not',
#  'traffic',
#  'with',
#  'the',
#  'breakers',
#  'of',
#  'the',
#  'peace',
#  'on',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'peace',
#  'the',
#  'responsibility',
#  'for',
#  'making',
#  'of',
#  'the',
#  'it',
#  'is',
#  'a',
#  'very',
#  'grave',
#  'rest',
#  'with',
#  'the',
#  'defenders',
#  'of',
#  'the',
#  'peace',
#  'we',
#  'are',
#  'not',
#  'unconscious',
#  'of',
#  'the',
#  'dictates',
#  'of',
#  'humanity',
#  'we',
#  'do',
#  'not',
#  'wish',
#  'to',
#  'see',
#  'unnecessary',
#  'or',
#  'unjustified',
#  'suffering',
#  'but',
#  'the',
#  'laws',
#  'of',
#  'go',
#  'd',
#  'and',
#  'of',
#  'man',
#  'have',
#  'been',
#  'violated',
#  'and',
#  'the',
#  'guilty',
#  'must',
#  'not',
#  'go',
#  'unpunished',
#  'nothing',
#  'shall',
#  'shake',
#  'our',
#  'determination',
#  'to',
#  'punish',
#  'the',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'we',
#  'must',
#  'pursue',
#  'them',
#  'to',
#  'the',
#  'ends',
#  'of',
#  'the',
#  'earth',
#  'lasting',
#  'peace',
#  'can',
#  'never',
#  'be',
#  'secured',
#  'if',
#  'we',
#  'permit',
#  'our',
#  'dangerous',
#  'opponents',
#  'to',
#  'plot',
#  'future',
#  'wars',
#  'with',
#  'impunity',
#  'at',
#  'any',
#  'mountain',
#  'retreat',
#  'however',
#  'distant',
#  'in',
#  'this',
#  'shrinking',
#  'world',
#  'it',
#  'is',
#  'futile',
#  'to',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  'real',
#  'security',
#  'will',
#  'be',
#  'found',
#  'only',
#  'in',
#  'law',
#  'and',
#  'in',
#  'justice',
#  'here',
#  'in',
#  'america',
#  'we',
#  'have',
#  'labored',
#  'long',
#  'and',
#  'hard',
#  'to',
#  'achieve',
#  'a',
#  'social',
#  'order',
#  'worthy',
#  'of',
#  'our',
#  'great',
#  'heritage',
#  'in',
#  'our',
#  'time',
#  'tremendous',
#  'progress',
#  'has',
#  'been',
#  'made',
#  'toward',
#  'a',
#  'really',
#  'democratic',
#  'way',
#  'of',
#  'life',
#  'let',
#  'me',
#  'assure',
#  'the',
#  'people',
#  'of',
#  'america',
#  'that',
#  'there',
#  'w',
#  'ill',
#  'be',
#  'no',
#  'relaxation',
#  'in',
#  'our',
#  'efforts',
#  'to',
#  'improve',
#  'the',
#  'lot',
#  'of',
#  'the',
#  'common',
#  'people',
#  'in',
#  'the',
#  'difficult',
#  'days',
#  'ahead',
#  'unquestionably',
#  'we',
#  'shall',
#  'face',
#  'problems',
#  'of',
#  'staggering',
#  'proportions',
#  'however',
#  'with',
#  'the',
#  'faith',
#  'of',
#  'our',
#  'fathers',
#  'in',
#  'our',
#  'hearts',
#  'we',
#  'do',
#  'not',
#  'fear',
#  'the',
#  'future',
#  'on',
#  'the',
#  'battlefields',
#  'we',
#  'have',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  'and',
#  'won',
#  'at',
#  'home',
#  'americans',
#  'will',
#  'not',
#  'be',
#  'less',
#  'resolute',
#  'we',
#  'shall',
#  'never',
#  'cease',
#  'our',
#  'struggle',
#  'to',
#  'preserve',
#  'and',
#  'maintain',
#  'our',
#  'american',
#  'way',
#  'of',
#  'life',
#  'at',
#  'this',
#  'moment',
#  'america',
#  'along',
#  'with',
#  'her',
#  'brave',
#  'allies',
#  'is',
#  'paying',
#  'again',
#  'a',
#  'heavy',
#  'price',
#  'for',
#  'the',
#  'defense',
#  'of',
#  'our',
#  'freedom',
#  'with',
#  'characteristic',
#  'energy',
#  'we',
#  'are',
#  'assisting',
#  'in',
#  'the',
#  'liberation',
#  'of',
#  'entire',
#  'nations',
#  'gradually',
#  'the',
#  'shackles',
#  'of',
#  'slavery',
#  'are',
#  'being',
#  'broken',
#  'by',
#  't',
#  'he',
#  'forces',
#  'of',
#  'freedom',
#  'all',
#  'of',
#  'us',
#  'are',
#  'praying',
#  'for',
#  'a',
#  'speedy',
#  'victory',
#  'every',
#  'day',
#  'peace',
#  'is',
#  'delayed',
#  'costs',
#  'a',
#  'terrible',
#  'toll',
#  'the',
#  'armies',
#  'of',
#  'liberation',
#  'today',
#  'are',
#  'bringing',
#  'to',
#  'an',
#  'end',
#  'hitler',
#  'ghastly',
#  'threat',
#  'to',
#  'dominate',
#  'the',
#  'world',
#  'tokyo',
#  'rocks',
#  'under',
#  'the',
#  'weight',
#  'of',
#  'our',
#  'bombs',
#  'the',
#  'grand',
#  'strategy',
#  'of',
#  'the',
#  'united',
#  'nations',
#  'war',
#  'has',
#  'been',
#  'determined',
#  'due',
#  'in',
#  'no',
#  'small',
#  'measure',
#  'to',
#  'the',
#  'vision',
#  'of',
#  'our',
#  'departed',
#  'commander',
#  'in',
#  'chief',
#  'we',
#  'are',
#  'now',
#  'carrying',
#  'out',
#  'our',
#  'part',
#  'of',
#  'that',
#  'strategy',
#  'under',
#  'the',
#  'able',
#  'direction',
#  'of',
#  'admiral',
#  'leahy',
#  'general',
#  'marshall',
#  'a',
#  'dmiral',
#  'king',
#  'general',
#  'arnold',
#  'general',
#  'eisenhower',
#  'admiral',
#  'nimitz',
#  'and',
#  'general',
#  'macarthur',
#  'i',
#  'want',
#  'the',
#  'entire',
#  'world',
#  'to',
#  'know',
#  'that',
#  'this',
#  'direction',
#  'must',
#  'and',
#  'will',
#  'and',
#  'unhampered',
#  'our',
#  'debt',
#  'to',
#  'the',
#  'heroic',
#  'men',
#  'and',
#  'valiant',
#  'women',
#  'in',
#  'the',
#  'service',
#  'of',
#  'our',
#  'country',
#  'can',
#  'never',
#  'be',
#  'repaid',
#  'they',
#  'have',
#  'earned',
#  'our',
#  'undying',
#  'gratitude',
#  'america',
#  'will',
#  'never',
#  'forget',
#  'their',
#  'sacrifices',
#  'because',
#  'of',
#  'these',
#  'sacrifices',
#  'the',
#  'dawn',
#  'of',
#  'justice',
#  'and',
#  'freedom',
#  'throughout',
#  'th',
#  'e',
#  'world',
#  'slowly',
#  'casts',
#  'its',
#  'gleam',
#  'across',
#  'the',
#  'horizon',
#  'our',
#  'forefathers',
#  'came',
#  'to',
#  'our',
#  'rugged',
#  'shores',
#  'in',
#  'search',
#  'of',
#  'religious',
#  'tolerance',
#  'political',
#  'freedom',
#  'and',
#  'economic',
#  'opportunity',
#  'for',
#  'those',
#  'fundamental',
#  'rights',
#  'they',
#  'risked',
#  'their',
#  'lives',
#  'we',
#  'well',
#  'know',
#  'today',
#  'that',
#  'such',
#  'rights',
#  'can',
#  'be',
#  'preserved',
#  'only',
#  'by',
#  'constant',
#  'vigilance',
#  'the',
#  'eternal',
#  'price',
#  'of',
#  'liberty',
#  'within',
#  'an',
#  'hour',
#  'after',
#  'i',
#  'took',
#  'the',
#  'oath',
#  'of',
#  'office',
#  'i',
#  'announced',
#  'that',
#  'the',
#  'san',
#  'francisco',
#  'conference',
#  'would',
#  'proceed',
#  'we',
#  'will',
#  'face',
#  'the',
#  'problems',
#  'of',
#  'peace',
#  ...]

# %%
def normalize(tokens:str):
    return [
        token.lower()
        for token in tokens
        if token.isalpha()
    ]

# %% [markdown]
# ## Part 6 – Stop Word Removal

# %% [markdown]
# 📌 Stop words are common words that often add little semantic meaning.

# %%
from nltk.corpus import stopwords

nltk.download("stopwords")

stop_words = set(stopwords.words("english"))

filtered_nltk = [t for t in normlized_nltk if t not in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\W1tcher\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
filtered_nltk
# Out:
# ['president',
#  'harry',
#  'truman',
#  'address',
#  'joint',
#  'session',
#  'congress',
#  'april',
#  'speaker',
#  'president',
#  'members',
#  'congress',
#  'heavy',
#  'heart',
#  'stand',
#  'friends',
#  'colleagues',
#  'congress',
#  'united',
#  'states',
#  'yesterday',
#  'laid',
#  'rest',
#  'mortal',
#  'remains',
#  'beloved',
#  'president',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'time',
#  'like',
#  'words',
#  'inadequate',
#  'eloquent',
#  'tribute',
#  'would',
#  'reverent',
#  'silence',
#  'yet',
#  'decisive',
#  'hour',
#  'world',
#  'events',
#  'moving',
#  'rapidly',
#  'silence',
#  'might',
#  'misunderstood',
#  'might',
#  'give',
#  'comfort',
#  'enemies',
#  'infinite',
#  'wisdom',
#  'almighty',
#  'god',
#  'seen',
#  'fit',
#  'take',
#  'us',
#  'great',
#  'man',
#  'loved',
#  'beloved',
#  'humanity',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'tremendous',
#  'void',
#  'left',
#  'passing',
#  'noble',
#  'soul',
#  'words',
#  'ease',
#  'aching',
#  'hearts',
#  'untold',
#  'millions',
#  'every',
#  'race',
#  'creed',
#  'color',
#  'world',
#  'knows',
#  'lost',
#  'heroic',
#  'champion',
#  'justice',
#  'freedom',
#  'tragic',
#  'fate',
#  'thrust',
#  'upon',
#  'us',
#  'grave',
#  'responsibilities',
#  'must',
#  'carry',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  'looked',
#  'forward',
#  'moved',
#  'forward',
#  'would',
#  'want',
#  'us',
#  'america',
#  'much',
#  'blood',
#  'already',
#  'shed',
#  'ideals',
#  'cherish',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'lived',
#  'died',
#  'dare',
#  'permit',
#  'even',
#  'momentary',
#  'pause',
#  'hard',
#  'fight',
#  'victory',
#  'today',
#  'entire',
#  'world',
#  'looking',
#  'america',
#  'enlightened',
#  'leadership',
#  'peace',
#  'progress',
#  'leadership',
#  'requires',
#  'vision',
#  'courage',
#  'tolerance',
#  'provided',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'highest',
#  'ideals',
#  'great',
#  'humility',
#  'call',
#  'upon',
#  'americans',
#  'help',
#  'keep',
#  'nation',
#  'united',
#  'defense',
#  'ideals',
#  'eloquently',
#  'proclaimed',
#  'franklin',
#  'roosevelt',
#  'want',
#  'turn',
#  'assure',
#  'fellow',
#  'americans',
#  'love',
#  'peace',
#  'liberty',
#  'throughout',
#  'world',
#  'support',
#  'defend',
#  'ideals',
#  'strength',
#  'heart',
#  'duty',
#  'shall',
#  'shirk',
#  'possible',
#  'misunderstanding',
#  'germany',
#  'japan',
#  'certain',
#  'beyond',
#  'shadow',
#  'doubt',
#  'america',
#  'continue',
#  'fight',
#  'freedom',
#  'vestige',
#  'resistance',
#  'remains',
#  'deeply',
#  'conscious',
#  'fact',
#  'much',
#  'hard',
#  'fighting',
#  'still',
#  'ahead',
#  'us',
#  'pay',
#  'heavy',
#  'price',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  'america',
#  'never',
#  'become',
#  'party',
#  'plan',
#  'partial',
#  'victory',
#  'settle',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'future',
#  'security',
#  'world',
#  'demand',
#  'surrender',
#  'traffic',
#  'breakers',
#  'peace',
#  'terms',
#  'peace',
#  'responsibility',
#  'making',
#  'grave',
#  'rest',
#  'defenders',
#  'peace',
#  'unconscious',
#  'dictates',
#  'humanity',
#  'wish',
#  'see',
#  'unnecessary',
#  'unjustified',
#  'suffering',
#  'laws',
#  'go',
#  'man',
#  'violated',
#  'guilty',
#  'must',
#  'go',
#  'unpunished',
#  'nothing',
#  'shall',
#  'shake',
#  'determination',
#  'punish',
#  'war',
#  'criminals',
#  'even',
#  'though',
#  'must',
#  'pursue',
#  'ends',
#  'earth',
#  'lasting',
#  'peace',
#  'never',
#  'secured',
#  'permit',
#  'dangerous',
#  'opponents',
#  'plot',
#  'future',
#  'wars',
#  'impunity',
#  'mountain',
#  'retreat',
#  'however',
#  'distant',
#  'shrinking',
#  'world',
#  'futile',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barriers',
#  'real',
#  'security',
#  'found',
#  'law',
#  'justice',
#  'america',
#  'labored',
#  'long',
#  'hard',
#  'achieve',
#  'social',
#  'order',
#  'worthy',
#  'great',
#  'heritage',
#  'time',
#  'tremendous',
#  'progress',
#  'made',
#  'toward',
#  'really',
#  'democratic',
#  'way',
#  'life',
#  'let',
#  'assure',
#  'people',
#  'america',
#  'w',
#  'ill',
#  'relaxation',
#  'efforts',
#  'improve',
#  'lot',
#  'common',
#  'people',
#  'difficult',
#  'days',
#  'ahead',
#  'unquestionably',
#  'shall',
#  'face',
#  'problems',
#  'staggering',
#  'proportions',
#  'however',
#  'faith',
#  'fathers',
#  'hearts',
#  'fear',
#  'future',
#  'battlefields',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  'home',
#  'americans',
#  'less',
#  'resolute',
#  'shall',
#  'never',
#  'cease',
#  'struggle',
#  'preserve',
#  'maintain',
#  'american',
#  'way',
#  'life',
#  'moment',
#  'america',
#  'along',
#  'brave',
#  'allies',
#  'paying',
#  'heavy',
#  'price',
#  'defense',
#  'freedom',
#  'characteristic',
#  'energy',
#  'assisting',
#  'liberation',
#  'entire',
#  'nations',
#  'gradually',
#  'shackles',
#  'slavery',
#  'broken',
#  'forces',
#  'freedom',
#  'us',
#  'praying',
#  'speedy',
#  'victory',
#  'every',
#  'day',
#  'peace',
#  'delayed',
#  'costs',
#  'terrible',
#  'toll',
#  'armies',
#  'liberation',
#  'today',
#  'bringing',
#  'end',
#  'hitler',
#  'ghastly',
#  'threat',
#  'dominate',
#  'world',
#  'tokyo',
#  'rocks',
#  'weight',
#  'bombs',
#  'grand',
#  'strategy',
#  'united',
#  'nations',
#  'war',
#  'determined',
#  'due',
#  'small',
#  'measure',
#  'vision',
#  'departed',
#  'commander',
#  'chief',
#  'carrying',
#  'part',
#  'strategy',
#  'able',
#  'direction',
#  'admiral',
#  'leahy',
#  'general',
#  'marshall',
#  'dmiral',
#  'king',
#  'general',
#  'arnold',
#  'general',
#  'eisenhower',
#  'admiral',
#  'nimitz',
#  'general',
#  'macarthur',
#  'want',
#  'entire',
#  'world',
#  'know',
#  'direction',
#  'must',
#  'unhampered',
#  'debt',
#  'heroic',
#  'men',
#  'valiant',
#  'women',
#  'service',
#  'country',
#  'never',
#  'repaid',
#  'earned',
#  'undying',
#  'gratitude',
#  'america',
#  'never',
#  'forget',
#  'sacrifices',
#  'sacrifices',
#  'dawn',
#  'justice',
#  'freedom',
#  'throughout',
#  'th',
#  'e',
#  'world',
#  'slowly',
#  'casts',
#  'gleam',
#  'across',
#  'horizon',
#  'forefathers',
#  'came',
#  'rugged',
#  'shores',
#  'search',
#  'religious',
#  'tolerance',
#  'political',
#  'freedom',
#  'economic',
#  'opportunity',
#  'fundamental',
#  'rights',
#  'risked',
#  'lives',
#  'well',
#  'know',
#  'today',
#  'rights',
#  'preserved',
#  'constant',
#  'vigilance',
#  'eternal',
#  'price',
#  'liberty',
#  'within',
#  'hour',
#  'took',
#  'oath',
#  'office',
#  'announced',
#  'san',
#  'francisco',
#  'conference',
#  'would',
#  'proceed',
#  'face',
#  'problems',
#  'peace',
#  'courage',
#  'faced',
#  'mastered',
#  'problems',
#  'war',
#  'memory',
#  'made',
#  'supreme',
#  'memory',
#  'fallen',
#  'shall',
#  'fail',
#  'enough',
#  'yearn',
#  'peace',
#  'must',
#  'work',
#  'necessary',
#  'fight',
#  'task',
#  'creating',
#  'sound',
#  'international',
#  'organization',
#  'complicated',
#  'difficult',
#  'yet',
#  'without',
#  'organization',
#  'rights',
#  'man',
#  'earth',
#  'protected',
#  'machi',
#  'nery',
#  'settlement',
#  'international',
#  'differences',
#  'must',
#  'found',
#  'without',
#  'machinery',
#  'entire',
#  'world',
#  'remain',
#  'armed',
#  'camp',
#  'world',
#  'doomed',
#  'deadly',
#  'conflict',
#  'devoid',
#  'hope',
#  'real',
#  'peace',
#  'fortunately',
#  'people',
#  'retained',
#  'hope',
#  'durable',
#  'peace',
#  'thoughtful',
#  'people',
#  'always',
#  'faith',
#  'ultimately',
#  'justice',
#  'must',
#  'triumph',
#  'past',
#  'experience',
#  'surely',
#  'indicates',
#  'without',
#  'justice',
#  'enduring',
#  'peace',
#  'becomes',
#  'impossible',
#  'bitter',
#  'despair',
#  'people',
#  'come',
#  'believe',
#  'wars',
#  'inevitable',
#  'tragic',
#  'fatalism',
#  'insist',
#  'wars',
#  'always',
#  'necessity',
#  'necessity',
#  'wars',
#  'always',
#  'defeatism',
#  'men',
#  'women',
#  'good',
#  'must',
#  'yield',
#  'outlook',
#  'humanity',
#  'hopeless',
#  'dark',
#  'hours',
#  'horrible',
#  'war',
#  'entire',
#  'nations',
#  'kept',
#  'going',
#  'something',
#  'warned',
#  'abject',
#  'submission',
#  'offered',
#  'salvation',
#  'overwhelming',
#  'power',
#  'hope',
#  'showed',
#  'way',
#  'victory',
#  'hope',
#  'become',
#  'secret',
#  'weapon',
#  'forces',
#  'liberation',
#  'aggressors',
#  'could',
#  'dominate',
#  'human',
#  'mind',
#  'long',
#  'hope',
#  'remains',
#  'spirit',
#  'man',
#  'never',
#  'crushed',
#  'hope',
#  'alone',
#  'sufficient',
#  'avert',
#  'war',
#  'must',
#  'hope',
#  'must',
#  'faith',
#  'enough',
#  'work',
#  'nations',
#  'maintain',
#  'peace',
#  'hope',
#  'enough',
#  'beat',
#  'back',
#  'aggressors',
#  'long',
#  'nations',
#  'unwilling',
#  'come',
#  'defense',
#  'aggressors',
#  'beaten',
#  'back',
#  'nations',
#  'united',
#  'defend',
#  'wars',
#  'future',
#  'prevented',
#  'nations',
#  'must',
#  'united',
#  'determination',
#  'keep',
#  'peace',
#  'law',
#  'nothing',
#  'essential',
#  'future',
#  'peace',
#  'world',
#  'continued',
#  'cooperation',
#  'nations',
#  'muster',
#  'force',
#  'necessary',
#  'defeat',
#  'conspiracy',
#  'axis',
#  'powers',
#  'dominate',
#  'world',
#  'great',
#  'states',
#  'special',
#  'responsibility',
#  'enforce',
#  'peace',
#  'responsibility',
#  'based',
#  'upon',
#  'obligations',
#  'resting',
#  'upon',
#  'states',
#  'large',
#  'small',
#  'use',
#  'force',
#  'international',
#  'relations',
#  'except',
#  'defense',
#  'law',
#  'respon',
#  'sibility',
#  'great',
#  'states',
#  'serve',
#  'dominate',
#  'world',
#  'build',
#  'foundation',
#  'enduring',
#  'peace',
#  'must',
#  'work',
#  'harmony',
#  'friends',
#  'abroad',
#  'must',
#  'united',
#  'support',
#  'people',
#  'even',
#  'experienced',
#  'pilot',
#  'bring',
#  'ship',
#  'safely',
#  'harbor',
#  'unless',
#  'full',
#  'cooperation',
#  'crew',
#  'benefit',
#  'every',
#  'individual',
#  'must',
#  'duty',
#  'appeal',
#  'every',
#  'american',
#  'regardless',
#  'party',
#  'race',
#  'creed',
#  'color',
#  'support',
#  'efforts',
#  'build',
#  'strong',
#  'lasting',
#  'united',
#  'nations',
#  'organization',
#  'members',
#  'congress',
#  'surely',
#  'know',
#  'feel',
#  'help',
#  'hope',
#  'complete',
#  'one',
#  'greatest',
#  'tasks',
#  'ever',
#  'assigned',
#  'public',
#  'servant',
#  'divine',
#  'guidance',
#  'help',
#  'find',
#  'new',
#  'passage',
#  'far',
#  'better',
#  'world',
#  'kindly',
#  'friendly',
#  'world',
#  'lasting',
#  'peace',
#  'confidence',
#  'depending',
#  'upon',
#  'destroy',
#  'greedy',
#  'tyrants',
#  'dreams',
#  'world',
#  'domination',
#  'continue',
#  'successive',
#  'generations',
#  'sacrifice',
#  'finest',
#  'youth',
#  'name',
#  'human',
#  'decency',
#  'civilization',
#  'rational',
#  'method',
#  'deciding',
#  'national',
#  'differences',
#  'must',
#  'found',
#  'america',
#  'must',
#  'assist',
#  'suffering',
#  'humanity',
#  'back',
#  'along',
#  'path',
#  'peaceful',
#  'progress',
#  'require',
#  'time',
#  'tolerance',
#  'shall',
#  'need',
#  'also',
#  'abiding',
#  'faith',
#  'people',
#  'kind',
#  'faith',
#  'courage',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'always',
#  'today',
#  'america',
#  'become',
#  'one',
#  'powerful',
#  'forces',
#  'good',
#  'earth',
#  'must',
#  'keep',
#  'achieved',
#  'world',
#  'leadership',
#  'depend',
#  'solely',
#  'upon',
#  'military',
#  'naval',
#  'might',
#  'learned',
#  'fight',
#  'nations',
#  'common',
#  'defense',
#  'freedom',
#  'must',
#  'learn',
#  'live',
#  'nations',
#  'mutual',
#  'good',
#  'must',
#  'learn',
#  'trade',
#  'nations',
#  'may',
#  'mutual',
#  'product',
#  'ion',
#  'increased',
#  'employment',
#  'better',
#  'standards',
#  'living',
#  'throughout',
#  'world',
#  'may',
#  'americans',
#  'live',
#  'glorious',
#  'heritage',
#  'way',
#  'america',
#  'may',
#  'well',
#  'lead',
#  'world',
#  'peace',
#  'prosperity',
#  'moment',
#  'heart',
#  'prayer',
#  'assumed',
#  'heavy',
#  'duties',
#  'humbly',
#  'pray',
#  'almighty',
#  'god',
#  'words',
#  'king',
#  'solomon',
#  'give',
#  'therefore',
#  'thy',
#  'servant',
#  'understanding',
#  'heart',
#  'judge',
#  'thy',
#  'people',
#  'may',
#  'discern',
#  'good',
#  'bad',
#  'able',
#  'judge',
#  'thy',
#  'great',
#  'people',
#  'ask',
#  'good',
#  'faithful',
#  'servant',
#  'lord',
#  'people']

# %% [markdown]
# ## Part 7 – Vocabulary and Frequency

# %% [markdown]
# 📌 The vocabulary is the set of unique tokens in a corpus.

# %%
from nltk.stem import WordNetLemmatizer

word_lemmatizer = WordNetLemmatizer()

lemmatized_words = [word_lemmatizer.lemmatize(word) for word in filtered_nltk]

lemmatized_words
# Out:
# ['president',
#  'harry',
#  'truman',
#  'address',
#  'joint',
#  'session',
#  'congress',
#  'april',
#  'speaker',
#  'president',
#  'member',
#  'congress',
#  'heavy',
#  'heart',
#  'stand',
#  'friend',
#  'colleague',
#  'congress',
#  'united',
#  'state',
#  'yesterday',
#  'laid',
#  'rest',
#  'mortal',
#  'remains',
#  'beloved',
#  'president',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'time',
#  'like',
#  'word',
#  'inadequate',
#  'eloquent',
#  'tribute',
#  'would',
#  'reverent',
#  'silence',
#  'yet',
#  'decisive',
#  'hour',
#  'world',
#  'event',
#  'moving',
#  'rapidly',
#  'silence',
#  'might',
#  'misunderstood',
#  'might',
#  'give',
#  'comfort',
#  'enemy',
#  'infinite',
#  'wisdom',
#  'almighty',
#  'god',
#  'seen',
#  'fit',
#  'take',
#  'u',
#  'great',
#  'man',
#  'loved',
#  'beloved',
#  'humanity',
#  'man',
#  'could',
#  'possibly',
#  'fill',
#  'tremendous',
#  'void',
#  'left',
#  'passing',
#  'noble',
#  'soul',
#  'word',
#  'ease',
#  'aching',
#  'heart',
#  'untold',
#  'million',
#  'every',
#  'race',
#  'creed',
#  'color',
#  'world',
#  'know',
#  'lost',
#  'heroic',
#  'champion',
#  'justice',
#  'freedom',
#  'tragic',
#  'fate',
#  'thrust',
#  'upon',
#  'u',
#  'grave',
#  'responsibility',
#  'must',
#  'carry',
#  'departed',
#  'leader',
#  'never',
#  'looked',
#  'backward',
#  'looked',
#  'forward',
#  'moved',
#  'forward',
#  'would',
#  'want',
#  'u',
#  'america',
#  'much',
#  'blood',
#  'already',
#  'shed',
#  'ideal',
#  'cherish',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'lived',
#  'died',
#  'dare',
#  'permit',
#  'even',
#  'momentary',
#  'pause',
#  'hard',
#  'fight',
#  'victory',
#  'today',
#  'entire',
#  'world',
#  'looking',
#  'america',
#  'enlightened',
#  'leadership',
#  'peace',
#  'progress',
#  'leadership',
#  'requires',
#  'vision',
#  'courage',
#  'tolerance',
#  'provided',
#  'united',
#  'nation',
#  'deeply',
#  'devoted',
#  'highest',
#  'ideal',
#  'great',
#  'humility',
#  'call',
#  'upon',
#  'american',
#  'help',
#  'keep',
#  'nation',
#  'united',
#  'defense',
#  'ideal',
#  'eloquently',
#  'proclaimed',
#  'franklin',
#  'roosevelt',
#  'want',
#  'turn',
#  'assure',
#  'fellow',
#  'american',
#  'love',
#  'peace',
#  'liberty',
#  'throughout',
#  'world',
#  'support',
#  'defend',
#  'ideal',
#  'strength',
#  'heart',
#  'duty',
#  'shall',
#  'shirk',
#  'possible',
#  'misunderstanding',
#  'germany',
#  'japan',
#  'certain',
#  'beyond',
#  'shadow',
#  'doubt',
#  'america',
#  'continue',
#  'fight',
#  'freedom',
#  'vestige',
#  'resistance',
#  'remains',
#  'deeply',
#  'conscious',
#  'fact',
#  'much',
#  'hard',
#  'fighting',
#  'still',
#  'ahead',
#  'u',
#  'pay',
#  'heavy',
#  'price',
#  'make',
#  'complete',
#  'victory',
#  'certain',
#  'america',
#  'never',
#  'become',
#  'party',
#  'plan',
#  'partial',
#  'victory',
#  'settle',
#  'merely',
#  'another',
#  'temporary',
#  'respite',
#  'would',
#  'surely',
#  'jeopardize',
#  'future',
#  'security',
#  'world',
#  'demand',
#  'surrender',
#  'traffic',
#  'breaker',
#  'peace',
#  'term',
#  'peace',
#  'responsibility',
#  'making',
#  'grave',
#  'rest',
#  'defender',
#  'peace',
#  'unconscious',
#  'dictate',
#  'humanity',
#  'wish',
#  'see',
#  'unnecessary',
#  'unjustified',
#  'suffering',
#  'law',
#  'go',
#  'man',
#  'violated',
#  'guilty',
#  'must',
#  'go',
#  'unpunished',
#  'nothing',
#  'shall',
#  'shake',
#  'determination',
#  'punish',
#  'war',
#  'criminal',
#  'even',
#  'though',
#  'must',
#  'pursue',
#  'end',
#  'earth',
#  'lasting',
#  'peace',
#  'never',
#  'secured',
#  'permit',
#  'dangerous',
#  'opponent',
#  'plot',
#  'future',
#  'war',
#  'impunity',
#  'mountain',
#  'retreat',
#  'however',
#  'distant',
#  'shrinking',
#  'world',
#  'futile',
#  'seek',
#  'safety',
#  'behind',
#  'geographical',
#  'barrier',
#  'real',
#  'security',
#  'found',
#  'law',
#  'justice',
#  'america',
#  'labored',
#  'long',
#  'hard',
#  'achieve',
#  'social',
#  'order',
#  'worthy',
#  'great',
#  'heritage',
#  'time',
#  'tremendous',
#  'progress',
#  'made',
#  'toward',
#  'really',
#  'democratic',
#  'way',
#  'life',
#  'let',
#  'assure',
#  'people',
#  'america',
#  'w',
#  'ill',
#  'relaxation',
#  'effort',
#  'improve',
#  'lot',
#  'common',
#  'people',
#  'difficult',
#  'day',
#  'ahead',
#  'unquestionably',
#  'shall',
#  'face',
#  'problem',
#  'staggering',
#  'proportion',
#  'however',
#  'faith',
#  'father',
#  'heart',
#  'fear',
#  'future',
#  'battlefield',
#  'frequently',
#  'faced',
#  'overwhelming',
#  'odds',
#  'home',
#  'american',
#  'less',
#  'resolute',
#  'shall',
#  'never',
#  'cease',
#  'struggle',
#  'preserve',
#  'maintain',
#  'american',
#  'way',
#  'life',
#  'moment',
#  'america',
#  'along',
#  'brave',
#  'ally',
#  'paying',
#  'heavy',
#  'price',
#  'defense',
#  'freedom',
#  'characteristic',
#  'energy',
#  'assisting',
#  'liberation',
#  'entire',
#  'nation',
#  'gradually',
#  'shackle',
#  'slavery',
#  'broken',
#  'force',
#  'freedom',
#  'u',
#  'praying',
#  'speedy',
#  'victory',
#  'every',
#  'day',
#  'peace',
#  'delayed',
#  'cost',
#  'terrible',
#  'toll',
#  'army',
#  'liberation',
#  'today',
#  'bringing',
#  'end',
#  'hitler',
#  'ghastly',
#  'threat',
#  'dominate',
#  'world',
#  'tokyo',
#  'rock',
#  'weight',
#  'bomb',
#  'grand',
#  'strategy',
#  'united',
#  'nation',
#  'war',
#  'determined',
#  'due',
#  'small',
#  'measure',
#  'vision',
#  'departed',
#  'commander',
#  'chief',
#  'carrying',
#  'part',
#  'strategy',
#  'able',
#  'direction',
#  'admiral',
#  'leahy',
#  'general',
#  'marshall',
#  'dmiral',
#  'king',
#  'general',
#  'arnold',
#  'general',
#  'eisenhower',
#  'admiral',
#  'nimitz',
#  'general',
#  'macarthur',
#  'want',
#  'entire',
#  'world',
#  'know',
#  'direction',
#  'must',
#  'unhampered',
#  'debt',
#  'heroic',
#  'men',
#  'valiant',
#  'woman',
#  'service',
#  'country',
#  'never',
#  'repaid',
#  'earned',
#  'undying',
#  'gratitude',
#  'america',
#  'never',
#  'forget',
#  'sacrifice',
#  'sacrifice',
#  'dawn',
#  'justice',
#  'freedom',
#  'throughout',
#  'th',
#  'e',
#  'world',
#  'slowly',
#  'cast',
#  'gleam',
#  'across',
#  'horizon',
#  'forefather',
#  'came',
#  'rugged',
#  'shore',
#  'search',
#  'religious',
#  'tolerance',
#  'political',
#  'freedom',
#  'economic',
#  'opportunity',
#  'fundamental',
#  'right',
#  'risked',
#  'life',
#  'well',
#  'know',
#  'today',
#  'right',
#  'preserved',
#  'constant',
#  'vigilance',
#  'eternal',
#  'price',
#  'liberty',
#  'within',
#  'hour',
#  'took',
#  'oath',
#  'office',
#  'announced',
#  'san',
#  'francisco',
#  'conference',
#  'would',
#  'proceed',
#  'face',
#  'problem',
#  'peace',
#  'courage',
#  'faced',
#  'mastered',
#  'problem',
#  'war',
#  'memory',
#  'made',
#  'supreme',
#  'memory',
#  'fallen',
#  'shall',
#  'fail',
#  'enough',
#  'yearn',
#  'peace',
#  'must',
#  'work',
#  'necessary',
#  'fight',
#  'task',
#  'creating',
#  'sound',
#  'international',
#  'organization',
#  'complicated',
#  'difficult',
#  'yet',
#  'without',
#  'organization',
#  'right',
#  'man',
#  'earth',
#  'protected',
#  'machi',
#  'nery',
#  'settlement',
#  'international',
#  'difference',
#  'must',
#  'found',
#  'without',
#  'machinery',
#  'entire',
#  'world',
#  'remain',
#  'armed',
#  'camp',
#  'world',
#  'doomed',
#  'deadly',
#  'conflict',
#  'devoid',
#  'hope',
#  'real',
#  'peace',
#  'fortunately',
#  'people',
#  'retained',
#  'hope',
#  'durable',
#  'peace',
#  'thoughtful',
#  'people',
#  'always',
#  'faith',
#  'ultimately',
#  'justice',
#  'must',
#  'triumph',
#  'past',
#  'experience',
#  'surely',
#  'indicates',
#  'without',
#  'justice',
#  'enduring',
#  'peace',
#  'becomes',
#  'impossible',
#  'bitter',
#  'despair',
#  'people',
#  'come',
#  'believe',
#  'war',
#  'inevitable',
#  'tragic',
#  'fatalism',
#  'insist',
#  'war',
#  'always',
#  'necessity',
#  'necessity',
#  'war',
#  'always',
#  'defeatism',
#  'men',
#  'woman',
#  'good',
#  'must',
#  'yield',
#  'outlook',
#  'humanity',
#  'hopeless',
#  'dark',
#  'hour',
#  'horrible',
#  'war',
#  'entire',
#  'nation',
#  'kept',
#  'going',
#  'something',
#  'warned',
#  'abject',
#  'submission',
#  'offered',
#  'salvation',
#  'overwhelming',
#  'power',
#  'hope',
#  'showed',
#  'way',
#  'victory',
#  'hope',
#  'become',
#  'secret',
#  'weapon',
#  'force',
#  'liberation',
#  'aggressor',
#  'could',
#  'dominate',
#  'human',
#  'mind',
#  'long',
#  'hope',
#  'remains',
#  'spirit',
#  'man',
#  'never',
#  'crushed',
#  'hope',
#  'alone',
#  'sufficient',
#  'avert',
#  'war',
#  'must',
#  'hope',
#  'must',
#  'faith',
#  'enough',
#  'work',
#  'nation',
#  'maintain',
#  'peace',
#  'hope',
#  'enough',
#  'beat',
#  'back',
#  'aggressor',
#  'long',
#  'nation',
#  'unwilling',
#  'come',
#  'defense',
#  'aggressor',
#  'beaten',
#  'back',
#  'nation',
#  'united',
#  'defend',
#  'war',
#  'future',
#  'prevented',
#  'nation',
#  'must',
#  'united',
#  'determination',
#  'keep',
#  'peace',
#  'law',
#  'nothing',
#  'essential',
#  'future',
#  'peace',
#  'world',
#  'continued',
#  'cooperation',
#  'nation',
#  'muster',
#  'force',
#  'necessary',
#  'defeat',
#  'conspiracy',
#  'axis',
#  'power',
#  'dominate',
#  'world',
#  'great',
#  'state',
#  'special',
#  'responsibility',
#  'enforce',
#  'peace',
#  'responsibility',
#  'based',
#  'upon',
#  'obligation',
#  'resting',
#  'upon',
#  'state',
#  'large',
#  'small',
#  'use',
#  'force',
#  'international',
#  'relation',
#  'except',
#  'defense',
#  'law',
#  'respon',
#  'sibility',
#  'great',
#  'state',
#  'serve',
#  'dominate',
#  'world',
#  'build',
#  'foundation',
#  'enduring',
#  'peace',
#  'must',
#  'work',
#  'harmony',
#  'friend',
#  'abroad',
#  'must',
#  'united',
#  'support',
#  'people',
#  'even',
#  'experienced',
#  'pilot',
#  'bring',
#  'ship',
#  'safely',
#  'harbor',
#  'unless',
#  'full',
#  'cooperation',
#  'crew',
#  'benefit',
#  'every',
#  'individual',
#  'must',
#  'duty',
#  'appeal',
#  'every',
#  'american',
#  'regardless',
#  'party',
#  'race',
#  'creed',
#  'color',
#  'support',
#  'effort',
#  'build',
#  'strong',
#  'lasting',
#  'united',
#  'nation',
#  'organization',
#  'member',
#  'congress',
#  'surely',
#  'know',
#  'feel',
#  'help',
#  'hope',
#  'complete',
#  'one',
#  'greatest',
#  'task',
#  'ever',
#  'assigned',
#  'public',
#  'servant',
#  'divine',
#  'guidance',
#  'help',
#  'find',
#  'new',
#  'passage',
#  'far',
#  'better',
#  'world',
#  'kindly',
#  'friendly',
#  'world',
#  'lasting',
#  'peace',
#  'confidence',
#  'depending',
#  'upon',
#  'destroy',
#  'greedy',
#  'tyrant',
#  'dream',
#  'world',
#  'domination',
#  'continue',
#  'successive',
#  'generation',
#  'sacrifice',
#  'finest',
#  'youth',
#  'name',
#  'human',
#  'decency',
#  'civilization',
#  'rational',
#  'method',
#  'deciding',
#  'national',
#  'difference',
#  'must',
#  'found',
#  'america',
#  'must',
#  'assist',
#  'suffering',
#  'humanity',
#  'back',
#  'along',
#  'path',
#  'peaceful',
#  'progress',
#  'require',
#  'time',
#  'tolerance',
#  'shall',
#  'need',
#  'also',
#  'abiding',
#  'faith',
#  'people',
#  'kind',
#  'faith',
#  'courage',
#  'franklin',
#  'delano',
#  'roosevelt',
#  'always',
#  'today',
#  'america',
#  'become',
#  'one',
#  'powerful',
#  'force',
#  'good',
#  'earth',
#  'must',
#  'keep',
#  'achieved',
#  'world',
#  'leadership',
#  'depend',
#  'solely',
#  'upon',
#  'military',
#  'naval',
#  'might',
#  'learned',
#  'fight',
#  'nation',
#  'common',
#  'defense',
#  'freedom',
#  'must',
#  'learn',
#  'live',
#  'nation',
#  'mutual',
#  'good',
#  'must',
#  'learn',
#  'trade',
#  'nation',
#  'may',
#  'mutual',
#  'product',
#  'ion',
#  'increased',
#  'employment',
#  'better',
#  'standard',
#  'living',
#  'throughout',
#  'world',
#  'may',
#  'american',
#  'live',
#  'glorious',
#  'heritage',
#  'way',
#  'america',
#  'may',
#  'well',
#  'lead',
#  'world',
#  'peace',
#  'prosperity',
#  'moment',
#  'heart',
#  'prayer',
#  'assumed',
#  'heavy',
#  'duty',
#  'humbly',
#  'pray',
#  'almighty',
#  'god',
#  'word',
#  'king',
#  'solomon',
#  'give',
#  'therefore',
#  'thy',
#  'servant',
#  'understanding',
#  'heart',
#  'judge',
#  'thy',
#  'people',
#  'may',
#  'discern',
#  'good',
#  'bad',
#  'able',
#  'judge',
#  'thy',
#  'great',
#  'people',
#  'ask',
#  'good',
#  'faithful',
#  'servant',
#  'lord',
#  'people']

# %% [markdown]
# # Stemming vs Lemmatization
#
# Stemming and lemmatization are both normalization techniques, but they make very different trade-offs.
#
# Stemming is fast and rule-based but can distort meaning
#
# Lemmatization is slower but linguistically informed
#
# In industry, the choice depends on task, domain, and interpretability requirements.

# %% [markdown]
# “democracy” → “democraci”
#
# stems are not necessarily real words

# %%
from nltk.stem import PorterStemmer

word_stemmer = PorterStemmer()

words_stemmed = [word_stemmer.stem(word) for word in filtered_nltk]

print(words_stemmed)
# Out:
# ['presid', 'harri', 'truman', 'address', 'joint', 'session', 'congress', 'april', 'speaker', 'presid', 'member', 'congress', 'heavi', 'heart', 'stand', 'friend', 'colleagu', 'congress', 'unit', 'state', 'yesterday', 'laid', 'rest', 'mortal', 'remain', 'belov', 'presid', 'franklin', 'delano', 'roosevelt', 'time', 'like', 'word', 'inadequ', 'eloqu', 'tribut', 'would', 'rever', 'silenc', 'yet', 'decis', 'hour', 'world', 'event', 'move', 'rapidli', 'silenc', 'might', 'misunderstood', 'might', 'give', 'comfort', 'enemi', 'infinit', 'wisdom', 'almighti', 'god', 'seen', 'fit', 'take', 'us', 'great', 'man', 'love', 'belov', 'human', 'man', 'could', 'possibl', 'fill', 'tremend', 'void', 'left', 'pass', 'nobl', 'soul', 'word', 'eas', 'ach', 'heart', 'untold', 'million', 'everi', 'race', 'creed', 'color', 'world', 'know', 'lost', 'heroic', 'champion', 'justic', 'freedom', 'tragic', 'fate', 'thrust', 'upon', 'us', 'grave', 'respons', 'must', 'carri', 'depart', 'leader', 'never', 'look', 'backward', 'look', 'forward', 'move', 'forward', 'would', 'want', 'us', 'america', 'much', 'blood', 'alreadi', 'shed', 'ideal', 'cherish', 'franklin', 'delano', 'roosevelt', 'live', 'die', 'dare', 'permit', 'even', 'momentari', 'paus', 'hard', 'fight', 'victori', 'today', 'entir', 'world', 'look', 'america', 'enlighten', 'leadership', 'peac', 'progress', 'leadership', 'requir', 'vision', 'courag', 'toler', 'provid', 'unit', 'nation', 'deepli', 'devot', 'highest', 'ideal', 'great', 'humil', 'call', 'upon', 'american', 'help', 'keep', 'nation', 'unit', 'defens', 'ideal', 'eloqu', 'proclaim', 'franklin', 'roosevelt', 'want', 'turn', 'assur', 'fellow', 'american', 'love', 'peac', 'liberti', 'throughout', 'world', 'support', 'defend', 'ideal', 'strength', 'heart', 'duti', 'shall', 'shirk', 'possibl', 'misunderstand', 'germani', 'japan', 'certain', 'beyond', 'shadow', 'doubt', 'america', 'continu', 'fight', 'freedom', 'vestig', 'resist', 'remain', 'deepli', 'consciou', 'fact', 'much', 'hard', 'fight', 'still', 'ahead', 'us', 'pay', 'heavi', 'price', 'make', 'complet', 'victori', 'certain', 'america', 'never', 'becom', 'parti', 'plan', 'partial', 'victori', 'settl', 'mere', 'anoth', 'temporari', 'respit', 'would', 'sure', 'jeopard', 'futur', 'secur', 'world', 'demand', 'surrend', 'traffic', 'breaker', 'peac', 'term', 'peac', 'respons', 'make', 'grave', 'rest', 'defend', 'peac', 'unconsci', 'dictat', 'human', 'wish', 'see', 'unnecessari', 'unjustifi', 'suffer', 'law', 'go', 'man', 'violat', 'guilti', 'must', 'go', 'unpunish', 'noth', 'shall', 'shake', 'determin', 'punish', 'war', 'crimin', 'even', 'though', 'must', 'pursu', 'end', 'earth', 'last', 'peac', 'never', 'secur', 'permit', 'danger', 'oppon', 'plot', 'futur', 'war', 'impun', 'mountain', 'retreat', 'howev', 'distant', 'shrink', 'world', 'futil', 'seek', 'safeti', 'behind', 'geograph', 'barrier', 'real', 'secur', 'found', 'law', 'justic', 'america', 'labor', 'long', 'hard', 'achiev', 'social', 'order', 'worthi', 'great', 'heritag', 'time', 'tremend', 'progress', 'made', 'toward', 'realli', 'democrat', 'way', 'life', 'let', 'assur', 'peopl', 'america', 'w', 'ill', 'relax', 'effort', 'improv', 'lot', 'common', 'peopl', 'difficult', 'day', 'ahead', 'unquestion', 'shall', 'face', 'problem', 'stagger', 'proport', 'howev', 'faith', 'father', 'heart', 'fear', 'futur', 'battlefield', 'frequent', 'face', 'overwhelm', 'odd', 'home', 'american', 'less', 'resolut', 'shall', 'never', 'ceas', 'struggl', 'preserv', 'maintain', 'american', 'way', 'life', 'moment', 'america', 'along', 'brave', 'alli', 'pay', 'heavi', 'price', 'defens', 'freedom', 'characterist', 'energi', 'assist', 'liber', 'entir', 'nation', 'gradual', 'shackl', 'slaveri', 'broken', 'forc', 'freedom', 'us', 'pray', 'speedi', 'victori', 'everi', 'day', 'peac', 'delay', 'cost', 'terribl', 'toll', 'armi', 'liber', 'today', 'bring', 'end', 'hitler', 'ghastli', 'threat', 'domin', 'world', 'tokyo', 'rock', 'weight', 'bomb', 'grand', 'strategi', 'unit', 'nation' ...

# %% [markdown]
# ### spaCy does not include a built-in stemmer by default.
#
# This is not a limitation. It is a design choice.
#
# spaCy prioritizes:
#
# - linguistically informed processing
#
# - lemmatization over stemming
#
# However, in real pipelines, you can still perform stemming alongside spaCy.

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

spacy_tokens = [token.text.lower() for token in doc if token.is_alpha]

spacy_stemmed_tokens = [stemmer.stem(token) for token in spacy_tokens]

print(spacy_tokens)

print(spacy_stemmed_tokens)
# Out:
# ['president', 'harry', 'truman', 'address', 'before', 'a', 'joint', 'session', 'of', 'the', 'congress', 'april', 'speaker', 'president', 'members', 'of', 'the', 'congress', 'it', 'is', 'with', 'a', 'heavy', 'heart', 'that', 'i', 'stand', 'before', 'you', 'my', 'friends', 'and', 'colleagues', 'in', 'the', 'congress', 'of', 'the', 'united', 'states', 'only', 'yesterday', 'we', 'laid', 'to', 'rest', 'the', 'mortal', 'remains', 'of', 'our', 'beloved', 'president', 'franklin', 'delano', 'roosevelt', 'at', 'a', 'time', 'like', 'this', 'words', 'are', 'inadequate', 'the', 'most', 'eloquent', 'tribute', 'would', 'be', 'a', 'reverent', 'silence', 'yet', 'in', 'this', 'decisive', 'hour', 'when', 'world', 'events', 'are', 'moving', 'so', 'rapidly', 'our', 'silence', 'might', 'be', 'misunderstood', 'and', 'might', 'give', 'comfort', 'to', 'our', 'enemies', 'in', 'his', 'infinite', 'wisdom', 'almighty', 'god', 'has', 'seen', 'fit', 'to', 'take', 'from', 'us', 'a', 'great', 'man', 'who', 'loved', 'and', 'was', 'beloved', 'by', 'all', 'humanity', 'no', 'man', 'could', 'possibly', 'fill', 'the', 'tremendous', 'void', 'left', 'by', 'the', 'passing', 'of', 'that', 'noble', 'soul', 'no', 'words', 'can', 'ease', 'the', 'aching', 'hearts', 'of', 'untold', 'millions', 'of', 'every', 'race', 'creed', 'and', 'color', 'the', 'world', 'knows', 'it', 'has', 'lost', 'a', 'heroic', 'champion', 'of', 'justice', 'and', 'freedom', 'tragic', 'fate', 'has', 'thrust', 'upon', 'us', 'grave', 'responsibilities', 'we', 'must', 'carry', 'on', 'our', 'departed', 'leader', 'never', 'looked', 'backward', 'he', 'looked', 'forward', 'and', 'moved', 'forward', 'that', 'is', 'what', 'he', 'would', 'want', 'us', 'to', 'do', 'that', 'is', 'what', 'america', 'will', 'do', 'so', 'much', 'blood', 'has', 'already', 'been', 'shed', 'for', 'the', 'ideals', 'which', 'we', 'cherish', 'and', 'for', 'which', 'franklin', 'delano', 'roosevelt', 'lived', 'and', 'died', 'that', 'we', 'dare', 'not', 'permit', 'even', 'a', 'momentary', 'pause', 'in', 'the', 'hard', 'fight', 'for', 'victory', 'today', 'the', 'entire', 'world', 'is', 'looking', 'to', 'america', 'for', 'enlightened', 'leadership', 'to', 'peace', 'and', 'progress', 'such', 'a', 'leadership', 'requires', 'vision', 'courage', 'and', 'tolerance', 'it', 'can', 'be', 'provided', 'only', 'by', 'a', 'united', 'nation', 'deeply', 'devoted', 'to', 'the', 'highest', 'ideals', 'with', 'great', 'humility', 'i', 'call', 'upon', 'all', 'americans', 'to', 'help', 'me', 'keep', 'our', 'nation', 'united', 'in', 'defense', 'of', 'those', 'ideals', 'which', 'have', 'been', 'so', 'eloquently', 'proclaimed', 'by', 'franklin', 'roosevelt', 'i', 'want', 'in', 'turn', 'to', 'assure', 'my', 'fellow', 'americans', 'and', 'all', 'of', 'those', 'who', 'love', 'peace', 'and', 'liberty', 'throughout', 'the', 'world', 'that', 'i', 'will', 'support', 'and', 'defend', 'those', 'ideals', 'with', 'all', 'my', 'strength', 'and', 'all', 'my', 'heart', 'that', 'is', 'my', 'duty', 'and', 'i', 'shall', 'not', 'shirk', 'it', 'so', 'that', 'there', 'can', 'be', 'no', 'possible', 'misunderstanding', 'both', 'germany', 'and', 'japan', 'can', 'be', 'certain', 'beyond', 'any', 'shadow', 'of', 'a', 'doubt', 'that', 'america', 'will', 'continue', 'the', 'fight', 'for', 'freedom', 'until', 'no', 'vestige', 'of', 'resistance', 'remains', 'we', 'are', 'deeply', 'conscious', 'of', 'the', 'fact', 'that', 'much', 'hard', 'fighting', 'is', 'still', 'ahead', 'of', 'us', 'having', 'to', 'pay', 'such', 'a', 'heavy', 'price', 'to', 'make', 'complete', 'victory', 'certain', 'america', 'will', 'never', 'become', 'a', 'party', 'to', 'any', 'plan', 'for', 'partial', 'victory', 'to', 'settle', 'for', 'merely', 'another', 'temporary', 'respite', 'would', 'surely', 'jeopardize', 'the', 'future', 'security', 'of', 'all', 'the', 'world', 'our', 'demand', 'has', 'been', 'and', 'it', 'remains', 'unconditional', 'surrender', 'we', 'will', 'not', 'traffic', 'with', 'the', 'breakers', 'of', 'the',  ...
# ['presid', 'harri', 'truman', 'address', 'befor', 'a', 'joint', 'session', 'of', 'the', 'congress', 'april', 'speaker', 'presid', 'member', 'of', 'the', 'congress', 'it', 'is', 'with', 'a', 'heavi', 'heart', 'that', 'i', 'stand', 'befor', 'you', 'my', 'friend', 'and', 'colleagu', 'in', 'the', 'congress', 'of', 'the', 'unit', 'state', 'onli', 'yesterday', 'we', 'laid', 'to', 'rest', 'the', 'mortal', 'remain', 'of', 'our', 'belov', 'presid', 'franklin', 'delano', 'roosevelt', 'at', 'a', 'time', 'like', 'thi', 'word', 'are', 'inadequ', 'the', 'most', 'eloqu', 'tribut', 'would', 'be', 'a', 'rever', 'silenc', 'yet', 'in', 'thi', 'decis', 'hour', 'when', 'world', 'event', 'are', 'move', 'so', 'rapidli', 'our', 'silenc', 'might', 'be', 'misunderstood', 'and', 'might', 'give', 'comfort', 'to', 'our', 'enemi', 'in', 'hi', 'infinit', 'wisdom', 'almighti', 'god', 'ha', 'seen', 'fit', 'to', 'take', 'from', 'us', 'a', 'great', 'man', 'who', 'love', 'and', 'wa', 'belov', 'by', 'all', 'human', 'no', 'man', 'could', 'possibl', 'fill', 'the', 'tremend', 'void', 'left', 'by', 'the', 'pass', 'of', 'that', 'nobl', 'soul', 'no', 'word', 'can', 'eas', 'the', 'ach', 'heart', 'of', 'untold', 'million', 'of', 'everi', 'race', 'creed', 'and', 'color', 'the', 'world', 'know', 'it', 'ha', 'lost', 'a', 'heroic', 'champion', 'of', 'justic', 'and', 'freedom', 'tragic', 'fate', 'ha', 'thrust', 'upon', 'us', 'grave', 'respons', 'we', 'must', 'carri', 'on', 'our', 'depart', 'leader', 'never', 'look', 'backward', 'he', 'look', 'forward', 'and', 'move', 'forward', 'that', 'is', 'what', 'he', 'would', 'want', 'us', 'to', 'do', 'that', 'is', 'what', 'america', 'will', 'do', 'so', 'much', 'blood', 'ha', 'alreadi', 'been', 'shed', 'for', 'the', 'ideal', 'which', 'we', 'cherish', 'and', 'for', 'which', 'franklin', 'delano', 'roosevelt', 'live', 'and', 'die', 'that', 'we', 'dare', 'not', 'permit', 'even', 'a', 'momentari', 'paus', 'in', 'the', 'hard', 'fight', 'for', 'victori', 'today', 'the', 'entir', 'world', 'is', 'look', 'to', 'america', 'for', 'enlighten', 'leadership', 'to', 'peac', 'and', 'progress', 'such', 'a', 'leadership', 'requir', 'vision', 'courag', 'and', 'toler', 'it', 'can', 'be', 'provid', 'onli', 'by', 'a', 'unit', 'nation', 'deepli', 'devot', 'to', 'the', 'highest', 'ideal', 'with', 'great', 'humil', 'i', 'call', 'upon', 'all', 'american', 'to', 'help', 'me', 'keep', 'our', 'nation', 'unit', 'in', 'defens', 'of', 'those', 'ideal', 'which', 'have', 'been', 'so', 'eloqu', 'proclaim', 'by', 'franklin', 'roosevelt', 'i', 'want', 'in', 'turn', 'to', 'assur', 'my', 'fellow', 'american', 'and', 'all', 'of', 'those', 'who', 'love', 'peac', 'and', 'liberti', 'throughout', 'the', 'world', 'that', 'i', 'will', 'support', 'and', 'defend', 'those', 'ideal', 'with', 'all', 'my', 'strength', 'and', 'all', 'my', 'heart', 'that', 'is', 'my', 'duti', 'and', 'i', 'shall', 'not', 'shirk', 'it', 'so', 'that', 'there', 'can', 'be', 'no', 'possibl', 'misunderstand', 'both', 'germani', 'and', 'japan', 'can', 'be', 'certain', 'beyond', 'ani', 'shadow', 'of', 'a', 'doubt', 'that', 'america', 'will', 'continu', 'the', 'fight', 'for', 'freedom', 'until', 'no', 'vestig', 'of', 'resist', 'remain', 'we', 'are', 'deepli', 'consciou', 'of', 'the', 'fact', 'that', 'much', 'hard', 'fight', 'is', 'still', 'ahead', 'of', 'us', 'have', 'to', 'pay', 'such', 'a', 'heavi', 'price', 'to', 'make', 'complet', 'victori', 'certain', 'america', 'will', 'never', 'becom', 'a', 'parti', 'to', 'ani', 'plan', 'for', 'partial', 'victori', 'to', 'settl', 'for', 'mere', 'anoth', 'temporari', 'respit', 'would', 'sure', 'jeopard', 'the', 'futur', 'secur', 'of', 'all', 'the', 'world', 'our', 'demand', 'ha', 'been', 'and', 'it', 'remain', 'uncondit', 'surrend', 'we', 'will', 'not', 'traffic', 'with', 'the', 'breaker', 'of', 'the', 'peac', 'on', 'the', 'term', 'of', 'the', 'peac', 'the', 'respons', 'for', 'make', 'of', 'the', 'peac', 'and', 'it', 'is', 'a', 'veri', 'grave', 'respons', 'must', 'rest', 'with' ...

# %% [markdown]
# NLTK does support lemmatization, but it requires:
#
# - a lemmatizer
#
# - part-of-speech information to work well
#
# By default, NLTK’s lemmatizer assumes nouns

# %%
from nltk.stem import WordNetLemmatizer

word_net_lemmatizer = WordNetLemmatizer()

default_word_lemmatizer = [word_net_lemmatizer.lemmatize(word) for word in filtered_nltk]

for w, l in zip(filtered_nltk, default_word_lemmatizer):
    print(f"{w} -> {l}")
# Out:
# president -> president
# harry -> harry
# truman -> truman
# address -> address
# joint -> joint
# session -> session
# congress -> congress
# april -> april
# speaker -> speaker
# president -> president
# members -> member
# congress -> congress
# heavy -> heavy
# heart -> heart
# stand -> stand
# friends -> friend
# colleagues -> colleague
# congress -> congress
# united -> united
# states -> state
# yesterday -> yesterday
# laid -> laid
# rest -> rest
# mortal -> mortal
# remains -> remains
# beloved -> beloved
# president -> president
# franklin -> franklin
# delano -> delano
# roosevelt -> roosevelt
# time -> time
# like -> like
# words -> word
# inadequate -> inadequate
# eloquent -> eloquent
# tribute -> tribute
# would -> would
# reverent -> reverent
# silence -> silence
# yet -> yet
# decisive -> decisive
# hour -> hour
# world -> world
# events -> event
# moving -> moving
# rapidly -> rapidly
# silence -> silence
# might -> might
# misunderstood -> misunderstood
# might -> might
# give -> give
# comfort -> comfort
# enemies -> enemy
# infinite -> infinite
# wisdom -> wisdom
# almighty -> almighty
# god -> god
# seen -> seen
# fit -> fit
# take -> take
# us -> u
# great -> great
# man -> man
# loved -> loved
# beloved -> beloved
# humanity -> humanity
# man -> man
# could -> could
# possibly -> possibly
# fill -> fill
# tremendous -> tremendous
# void -> void
# left -> left
# passing -> passing
# noble -> noble
# soul -> soul
# words -> word
# ease -> ease
# aching -> aching
# hearts -> heart
# untold -> untold
# millions -> million
# every -> every
# race -> race
# creed -> creed
# color -> color
# world -> world
# knows -> know
# lost -> lost
# heroic -> heroic
# champion -> champion
# justice -> justice
# freedom -> freedom
# tragic -> tragic
# fate -> fate
# thrust -> thrust
# upon -> upon
# us -> u
# grave -> grave
# responsibilities -> responsibility
# must -> must
# carry -> carry
# departed -> departed
# leader -> leader
# never -> never
# looked -> looked
# backward -> backward
# looked -> looked
# forward -> forward
# moved -> moved
# forward -> forward
# would -> would
# want -> want
# us -> u
# america -> america
# much -> much
# blood -> blood
# already -> already
# shed -> shed
# ideals -> ideal
# cherish -> cherish
# franklin -> franklin
# delano -> delano
# roosevelt -> roosevelt
# lived -> lived
# died -> died
# dare -> dare
# permit -> permit
# even -> even
# momentary -> momentary
# pause -> pause
# hard -> hard
# fight -> fight
# victory -> victory
# today -> today
# entire -> entire
# world -> world
# looking -> looking
# america -> america
# enlightened -> enlightened
# leadership -> leadership
# peace -> peace
# progress -> progress
# leadership -> leadership
# requires -> requires
# vision -> vision
# courage -> courage
# tolerance -> tolerance
# provided -> provided
# united -> united
# nation -> nation
# deeply -> deeply
# devoted -> devoted
# highest -> highest
# ideals -> ideal
# great -> great
# humility -> humility
# call -> call
# upon -> upon
# americans -> american
# help -> help
# keep -> keep
# nation -> nation
# united -> united
# defense -> defense
# ideals -> ideal
# eloquently -> eloquently
# proclaimed -> proclaimed
# franklin -> franklin
# roosevelt -> roosevelt
# want -> want
# turn -> turn
# assure -> assure
# fellow -> fellow
# americans -> american
# love -> love
# peace -> peace
# liberty -> liberty
# throughout -> throughout
# world -> world
# support -> support
# defend -> defend
# ideals -> ideal
# strength -> strength
# heart -> heart
# duty -> duty
# shall -> shall
# shirk -> shirk
# possible -> possible
# misunderstanding -> misunderstanding
# germany -> germany
# japan -> japan
# certain -> certain
# beyond -> beyond
# shadow -> shadow
# doubt -> doubt
# america -> america
# continue -> continue
# fight -> fight
# freedom -> freedom
# vestige -> vestige
# resistance -> resistance
# remains -> remains
# deeply -> deeply
# conscious -> conscious
# fact -> fact
# much -> much
# hard -> hard
# fighting -> fighting
# still -> still
# ahead -> ahead
# us -> u
# pay -> pay
# heavy -> heavy
# price -> price
# make -> make
# complete -> complete
# victory -> victory
# certain -> certain
# america -> america
# never -> never
# become -> become
# party -> party
# plan -> plan
# partial -> partial
# victory -> victory
# settle -> settle
# merely -> merely
# another -> another
# temporary -> temporary
# respite -> respite
# would -> would
# surely -> surely
# jeopardize -> jeopardize
# future -> future
# security -> security
# world -> world
# demand -> demand
# surrender -> surrender
# traffic -> traffic
# breakers -> breaker
# peace -> peace
# terms -> term
# peace -> peace
# responsibility -> responsibility
# making -> making
# grave -> grave
# rest -> rest
# defenders -> defender
# peace -> peace
# unconscious -> unconscious
# dictates -> dictate
# humanity -> humanity
# wish -> wish
# see -> see
# unnecessary -> unnecessary
# unjustified -> unjustified
# suffering -> suffering
# laws -> law
# go -> go
# man -> man
# violated -> violated
# guilty -> guilty
# must -> must
# go -> go
# unpunished -> unpunished
# nothing -> nothing
# shall -> shall
# shake -> shake
# determination -> determination
# punish -> punish
# war -> war
# criminals -> criminal
# even -> even
# though -> though
# must -> must
# pursue -> pursue
# ends -> end
# earth -> earth
# lasting -> lasting
# peace -> peace
# never -> never
# secured -> secured
# permit -> permit
# dangerous -> dangerous
# opponents -> opponent
# plot -> plot
# future -> future
# wars -> war
# impunity -> impunity
# mountain -> mountain
# retreat -> retreat
# however -> however
# distant -> distant
# shrinking -> shrinking
# world -> world
# futile -> futile
# seek -> seek
# safety -> safety
# behind -> behind
# geographical -> geographical
# barriers -> barrier
# real -> real
# security -> security
# found -> found
# law -> law
# justice -> justice
# america -> america
# labored -> labored
# long -> long
# hard -> hard
# achieve -> achieve
# social -> social
# order -> order
# worthy -> worthy
# great -> great
# heritage -> heritage
# time -> time
# tremendous -> tremendous
# progress -> progress
# made -> made
# toward -> toward
# really -> really
# democratic -> democratic
# way -> way
# life -> life
# let -> let
# assure -> assure
# people -> people
# america -> america
# w -> w
# ill -> ill
# relaxation -> relaxation
# efforts -> effort
# improve -> improve
# lot -> lot
# common -> common
# people -> people
# difficult -> difficult
# days -> day
# ahead -> ahead
# unquestionably -> unquestionably
# shall -> shall
# face -> face
# problems -> problem
# staggering -> staggering
# proportions -> proportion
# however -> however
# faith -> faith
# fathers -> father
# hearts -> heart
# fear -> fear
# future -> future
# battlefields -> battlefield
# frequently -> frequently
# faced -> faced
# overwhelming -> overwhelming
# odds -> odds
# home -> home
# americans -> american
# less -> less
# resolute -> resolute
# shall -> shall
# never -> never
# cease -> cease
# struggle -> struggle
# preserve -> preserve
# maintain -> maintain
# american -> american
# way -> way
# life -> life
# moment -> moment
# america -> america
# along -> along
# brave -> brave
# allies -> ally
# paying -> paying
# heavy -> heavy
# price -> price
# defense -> defense
# freedom -> freedom
# characteristic -> characteristic
# energy -> energy
# assisting -> assisting
# liberation -> liberation
# entire -> entire
# nations -> nation
# gradually -> gradually
# shackles -> shackle
# slavery -> slavery
# broken -> broken
# forces -> force
# freedom -> freedom
# us -> u
# praying -> praying
# speedy -> speedy
# victory -> victory
# every -> every
# day -> day
# peace -> peace
# delayed -> delayed
# costs -> cost
# terrible -> terrible
# toll -> toll
# armies -> army
# liberation -> liberation
# today -> today
# bringing -> bringing
# end -> end
# hitler -> hitler
# ghastly -> ghastly
# threat -> threat
# dominate -> dominate
# world -> world
# tokyo -> tokyo
# rocks -> rock
# weight -> weight
# bombs -> bomb
# grand -> grand
# strategy -> strategy
# united -> united
# nations -> nation
# war -> war
# determined -> determined
# due -> due
# small -> small
# measure -> measure
# vision -> vision
# departed -> departed
# commander -> commander
# chief -> chief
# carrying -> carrying
# part -> part
# strategy -> strategy
# able -> able
# direction -> direction
# admiral -> admiral
# leahy -> leahy
# general -> general
# marshall -> marshall
# dmiral -> dmiral
# king -> king
# general -> general
# arnold -> arnold
# general -> general
# eisenhower -> eisenhower
# admiral -> admiral
# nimitz -> nimitz
# general -> general
# macarthur -> macarthur
# want -> want
# entire -> entire
# world -> world
# know -> know
# direction -> direction
# must -> must
# unhampered -> unhampered
# debt -> debt
# heroic -> heroic
# men -> men
# valiant -> valiant
# women -> woman
# service -> service
# country -> country
# never -> never
# repaid -> repaid
# earned -> earned
# undying -> undying
# gratitude -> gratitude
# america -> america
# never -> never
# forget -> forget
# sacrifices -> sacrifice
# sacrifices -> sacrifice
# dawn -> dawn
# justice -> justice
# freedom -> freedom
# throughout -> throughout
# th -> th
# e -> e
# world -> world
# slowly -> slowly
# casts -> cast
# gleam -> gleam
# across -> across
# horizon -> horizon
# forefathers -> forefather
# came -> came
# rugged -> rugged
# shores -> shore
# search -> search
# religious -> religious
# tolerance -> tolerance
# political -> political
# freedom -> freedom
# economic -> economic
# opportunity -> opportunity
# fundamental -> fundamental
# rights -> right
# risked -> risked
# lives -> life
# well -> well
# know -> know
# today -> today
# rights -> right
# preserved -> preserved
# constant -> constant
# vigilance -> vigilance
# eternal -> eternal
# price -> price
# liberty -> liberty
# within -> within
# hour -> hour
# took -> took
# oath -> oath
# office -> office
# announced -> announced
# san -> san
# francisco -> francisco
# conference -> conference
# would -> would
# proceed -> proceed
# face -> face
# problems -> problem
# peace -> peace
# courage -> courage
# faced -> faced
# mastered -> mastered
# problems -> problem
# war -> war
# memory -> memory
# made -> made
# supreme -> supreme
# memory -> memory
# fallen -> fallen
# shall -> shall
# fail -> fail
# enough -> enough
# yearn -> yearn
# peace -> peace
# must -> must
# work -> work
# necessary -> necessary
# fight -> fight
# task -> task
# creating -> creating
# sound -> sound
# international -> international
# organization -> organization
# complicated -> complicated
# difficult -> difficult
# yet -> yet
# without -> without
# organization -> organization
# rights -> right
# man -> man
# earth -> earth
# protected -> protected
# machi -> machi
# nery -> nery
# settlement -> settlement
# international -> international
# differences -> difference
# must -> must
# found -> found
# without -> without
# machinery -> machinery
# entire -> entire
# world -> world
# remain -> remain
# armed -> armed
# camp -> camp
# world -> world
# doomed -> doomed
# deadly -> deadly
# conflict -> conflict
# devoid -> devoid
# hope -> hope
# real -> real
# peace -> peace
# fortunately -> fortunately
# people -> people
# retained -> retained
# hope -> hope
# durable -> durable
# peace -> peace
# thoughtful -> thoughtful
# people -> people
# always -> always
# faith -> faith
# ultimately -> ultimately
# justice -> justice
# must -> must
# triumph -> triumph
# past -> past
# experience -> experience
# surely -> surely
# indicates -> indicates
# without -> without
# justice -> justice
# enduring -> enduring
# peace -> peace
# becomes -> becomes
# impossible -> impossible
# bitter -> bitter
# despair -> despair
# people -> people
# come -> come
# believe -> believe
# wars -> war
# inevitable -> inevitable
# tragic -> tragic
# fatalism -> fatalism
# insist -> insist
# wars -> war
# always -> always
# necessity -> necessity
# necessity -> necessity
# wars -> war
# always -> always
# defeatism -> defeatism
# men -> men
# women -> woman
# good -> good
# must -> must
# yield -> yield
# outlook -> outlook
# humanity -> humanity
# hopeless -> hopeless
# dark -> dark
# hours -> hour
# horrible -> horrible
# war -> war
# entire -> entire
# nations -> nation
# kept -> kept
# going -> going
# something -> something
# warned -> warned
# abject -> abject
# submission -> submission
# offered -> offered
# salvation -> salvation
# overwhelming -> overwhelming
# power -> power
# hope -> hope
# showed -> showed
# way -> way
# victory -> victory
# hope -> hope
# become -> become
# secret -> secret
# weapon -> weapon
# forces -> force
# liberation -> liberation
# aggressors -> aggressor
# could -> could
# dominate -> dominate
# human -> human
# mind -> mind
# long -> long
# hope -> hope
# remains -> remains
# spirit -> spirit
# man -> man
# never -> never
# crushed -> crushed
# hope -> hope
# alone -> alone
# sufficient -> sufficient
# avert -> avert
# war -> war
# must -> must
# hope -> hope
# must -> must
# faith -> faith
# enough -> enough
# work -> work
# nations -> nation
# maintain -> maintain
# peace -> peace
# hope -> hope
# enough -> enough
# beat -> beat
# back -> back
# aggressors -> aggressor
# long -> long
# nations -> nation
# unwilling -> unwilling
# come -> come
# defense -> defense
# aggressors -> aggressor
# beaten -> beaten
# back -> back
# nations -> nation
# united -> united
# defend -> defend
# wars -> war
# future -> future
# prevented -> prevented
# nations -> nation
# must -> must
# united -> united
# determination -> determination
# keep -> keep
# peace -> peace
# law -> law
# nothing -> nothing
# essential -> essential
# future -> future
# peace -> peace
# world -> world
# continued -> continued
# cooperation -> cooperation
# nations -> nation
# muster -> muster
# force -> force
# necessary -> necessary
# defeat -> defeat
# conspiracy -> conspiracy
# axis -> axis
# powers -> power
# dominate -> dominate
# world -> world
# great -> great
# states -> state
# special -> special
# responsibility -> responsibility
# enforce -> enforce
# peace -> peace
# responsibility -> responsibility
# based -> based
# upon -> upon
# obligations -> obligation
# resting -> resting
# upon -> upon
# states -> state
# large -> large
# small -> small
# use -> use
# force -> force
# international -> international
# relations -> relation
# except -> except
# defense -> defense
# law -> law
# respon -> respon
# sibility -> sibility
# great -> great
# states -> state
# serve -> serve
# dominate -> dominate
# world -> world
# build -> build
# foundation -> foundation
# enduring -> enduring
# peace -> peace
# must -> must
# work -> work
# harmony -> harmony
# friends -> friend
# abroad -> abroad
# must -> must
# united -> united
# support -> support
# people -> people
# even -> even
# experienced -> experienced
# pilot -> pilot
# bring -> bring
# ship -> ship
# safely -> safely
# harbor -> harbor
# unless -> unless
# full -> full
# cooperation -> cooperation
# crew -> crew
# benefit -> benefit
# every -> every
# individual -> individual
# must -> must
# duty -> duty
# appeal -> appeal
# every -> every
# american -> american
# regardless -> regardless
# party -> party
# race -> race
# creed -> creed
# color -> color
# support -> support
# efforts -> effort
# build -> build
# strong -> strong
# lasting -> lasting
# united -> united
# nations -> nation
# organization -> organization
# members -> member
# congress -> congress
# surely -> surely
# know -> know
# feel -> feel
# help -> help
# hope -> hope
# complete -> complete
# one -> one
# greatest -> greatest
# tasks -> task
# ever -> ever
# assigned -> assigned
# public -> public
# servant -> servant
# divine -> divine
# guidance -> guidance
# help -> help
# find -> find
# new -> new
# passage -> passage
# far -> far
# better -> better
# world -> world
# kindly -> kindly
# friendly -> friendly
# world -> world
# lasting -> lasting
# peace -> peace
# confidence -> confidence
# depending -> depending
# upon -> upon
# destroy -> destroy
# greedy -> greedy
# tyrants -> tyrant
# dreams -> dream
# world -> world
# domination -> domination
# continue -> continue
# successive -> successive
# generations -> generation
# sacrifice -> sacrifice
# finest -> finest
# youth -> youth
# name -> name
# human -> human
# decency -> decency
# civilization -> civilization
# rational -> rational
# method -> method
# deciding -> deciding
# national -> national
# differences -> difference
# must -> must
# found -> found
# america -> america
# must -> must
# assist -> assist
# suffering -> suffering
# humanity -> humanity
# back -> back
# along -> along
# path -> path
# peaceful -> peaceful
# progress -> progress
# require -> require
# time -> time
# tolerance -> tolerance
# shall -> shall
# need -> need
# also -> also
# abiding -> abiding
# faith -> faith
# people -> people
# kind -> kind
# faith -> faith
# courage -> courage
# franklin -> franklin
# delano -> delano
# roosevelt -> roosevelt
# always -> always
# today -> today
# america -> america
# become -> become
# one -> one
# powerful -> powerful
# forces -> force
# good -> good
# earth -> earth
# must -> must
# keep -> keep
# achieved -> achieved
# world -> world
# leadership -> leadership
# depend -> depend
# solely -> solely
# upon -> upon
# military -> military
# naval -> naval
# might -> might
# learned -> learned
# fight -> fight
# nations -> nation
# common -> common
# defense -> defense
# freedom -> freedom
# must -> must
# learn -> learn
# live -> live
# nations -> nation
# mutual -> mutual
# good -> good
# must -> must
# learn -> learn
# trade -> trade
# nations -> nation
# may -> may
# mutual -> mutual
# product -> product
# ion -> ion
# increased -> increased
# employment -> employment
# better -> better
# standards -> standard
# living -> living
# throughout -> throughout
# world -> world
# may -> may
# americans -> american
# live -> live
# glorious -> glorious
# heritage -> heritage
# way -> way
# america -> america
# may -> may
# well -> well
# lead -> lead
# world -> world
# peace -> peace
# prosperity -> prosperity
# moment -> moment
# heart -> heart
# prayer -> prayer
# assumed -> assumed
# heavy -> heavy
# duties -> duty
# humbly -> humbly
# pray -> pray
# almighty -> almighty
# god -> god
# words -> word
# king -> king
# solomon -> solomon
# give -> give
# therefore -> therefore
# thy -> thy
# servant -> servant
# understanding -> understanding
# heart -> heart
# judge -> judge
# thy -> thy
# people -> people
# may -> may
# discern -> discern
# good -> good
# bad -> bad
# able -> able
# judge -> judge
# thy -> thy
# great -> great
# people -> people
# ask -> ask
# good -> good
# faithful -> faithful
# servant -> servant
# lord -> lord
# people -> people

# %% [markdown]
# Notice that many verbs are not lemmatized correctly.
# This is because NLTK’s lemmatizer defaults to noun POS tags.

# %%
from nltk.corpus import wordnet

nltk.download("averaged_perceptron_tagger")
nltk.download("averaged_perceptron_tagger_eng")

def get_wordnet_pos(tag):
    if tag.startswith("V"):
        return wordnet.VERB
    if tag.startswith("J"):
        return wordnet.ADJ
    if tag.startswith("R"):
        return wordnet.ADV
    return wordnet.NOUN

tagged_words = nltk.pos_tag(filtered_nltk)

pos_aware_lemmatize = [
    word_lemmatizer.lemmatize(word, get_wordnet_pos(tag))
    for word, tag in tagged_words
]

for (word, tag), lemma in zip(tagged_words, pos_aware_lemmatize):
    print(f"{word} ({tag}) -> {lemma}")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\W1tcher\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\W1tcher\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# president (NN) -> president
# harry (NN) -> harry
# truman (NN) -> truman
# address (NN) -> address
# joint (NN) -> joint
# session (NN) -> session
# congress (NN) -> congress
# april (JJ) -> april
# speaker (NN) -> speaker
# president (NN) -> president
# members (NNS) -> member
# congress (VBP) -> congress
# heavy (JJ) -> heavy
# heart (NN) -> heart
# stand (VB) -> stand
# friends (NNS) -> friend
# colleagues (NNS) -> colleague
# congress (VBP) -> congress
# united (JJ) -> united
# states (NNS) -> state
# yesterday (NN) -> yesterday
# laid (VBD) -> lay
# rest (JJS) -> rest
# mortal (NN) -> mortal
# remains (VBZ) -> remain
# beloved (JJ) -> beloved
# president (NN) -> president
# franklin (NN) -> franklin
# delano (NN) -> delano
# roosevelt (VBD) -> roosevelt
# time (NN) -> time
# like (IN) -> like
# words (NNS) -> word
# inadequate (JJ) -> inadequate
# eloquent (JJ) -> eloquent
# tribute (NN) -> tribute
# would (MD) -> would
# reverent (VB) -> reverent
# silence (NN) -> silence
# yet (RB) -> yet
# decisive (JJ) -> decisive
# hour (NN) -> hour
# world (NN) -> world
# events (NNS) -> event
# moving (VBG) -> move
# rapidly (RB) -> rapidly
# silence (NN) -> silence
# might (MD) -> might
# misunderstood (VB) -> misunderstand
# might (MD) -> might
# give (VB) -> give
# comfort (NN) -> comfort
# enemies (NNS) -> enemy
# infinite (VBP) -> infinite
# wisdom (NN) -> wisdom
# almighty (NN) -> almighty
# god (NN) -> god
# seen (VBN) -> see
# fit (JJ) -> fit
# take (VBP) -> take
# us (PRP) -> u
# great (JJ) -> great
# man (NN) -> man
# loved (VBD) -> love
# beloved (JJ) -> beloved
# humanity (NN) -> humanity
# man (NN) -> man
# could (MD) -> could
# possibly (RB) -> possibly
# fill (VB) -> fill
# tremendous (JJ) -> tremendous
# void (NN) -> void
# left (VBD) -> leave
# passing (VBG) -> pass
# noble (JJ) -> noble
# soul (NN) -> soul
# words (NNS) -> word
# ease (VBP) -> ease
# aching (VBG) -> ache
# hearts (NNS) -> heart
# untold (JJ) -> untold
# millions (NNS) -> million
# every (DT) -> every
# race (NN) -> race
# creed (NN) -> creed
# color (NN) -> color
# world (NN) -> world
# knows (VBZ) -> know
# lost (VBN) -> lose
# heroic (JJ) -> heroic
# champion (NN) -> champion
# justice (NN) -> justice
# freedom (NN) -> freedom
# tragic (JJ) -> tragic
# fate (NN) -> fate
# thrust (NN) -> thrust
# upon (IN) -> upon
# us (PRP) -> u
# grave (VBP) -> grave
# responsibilities (NNS) -> responsibility
# must (MD) -> must
# carry (VB) -> carry
# departed (JJ) -> departed
# leader (NN) -> leader
# never (RB) -> never
# looked (VBD) -> look
# backward (NN) -> backward
# looked (VBD) -> look
# forward (RB) -> forward
# moved (VBN) -> move
# forward (RB) -> forward
# would (MD) -> would
# want (VB) -> want
# us (PRP) -> u
# america (RB) -> america
# much (JJ) -> much
# blood (NN) -> blood
# already (RB) -> already
# shed (VBD) -> shed
# ideals (NNS) -> ideal
# cherish (JJ) -> cherish
# franklin (JJ) -> franklin
# delano (NN) -> delano
# roosevelt (VBD) -> roosevelt
# lived (JJ) -> lived
# died (VBD) -> die
# dare (JJ) -> dare
# permit (NN) -> permit
# even (RB) -> even
# momentary (JJ) -> momentary
# pause (RB) -> pause
# hard (JJ) -> hard
# fight (NN) -> fight
# victory (NN) -> victory
# today (NN) -> today
# entire (JJ) -> entire
# world (NN) -> world
# looking (VBG) -> look
# america (NN) -> america
# enlightened (VBD) -> enlighten
# leadership (NN) -> leadership
# peace (NN) -> peace
# progress (NN) -> progress
# leadership (NN) -> leadership
# requires (VBZ) -> require
# vision (JJ) -> vision
# courage (NN) -> courage
# tolerance (NN) -> tolerance
# provided (VBD) -> provide
# united (JJ) -> united
# nation (NN) -> nation
# deeply (RB) -> deeply
# devoted (VBN) -> devote
# highest (JJS) -> high
# ideals (NNS) -> ideal
# great (JJ) -> great
# humility (NN) -> humility
# call (NN) -> call
# upon (IN) -> upon
# americans (NNS) -> american
# help (VBP) -> help
# keep (VB) -> keep
# nation (NN) -> nation
# united (JJ) -> united
# defense (NN) -> defense
# ideals (NNS) -> ideal
# eloquently (RB) -> eloquently
# proclaimed (VBD) -> proclaim
# franklin (JJ) -> franklin
# roosevelt (NN) -> roosevelt
# want (VBP) -> want
# turn (NN) -> turn
# assure (NN) -> assure
# fellow (JJ) -> fellow
# americans (NNS) -> american
# love (VBP) -> love
# peace (NN) -> peace
# liberty (NN) -> liberty
# throughout (IN) -> throughout
# world (NN) -> world
# support (NN) -> support
# defend (VBP) -> defend
# ideals (NNS) -> ideal
# strength (NN) -> strength
# heart (NN) -> heart
# duty (NN) -> duty
# shall (MD) -> shall
# shirk (VB) -> shirk
# possible (JJ) -> possible
# misunderstanding (VBG) -> misunderstand
# germany (NN) -> germany
# japan (NN) -> japan
# certain (JJ) -> certain
# beyond (IN) -> beyond
# shadow (JJ) -> shadow
# doubt (NN) -> doubt
# america (NN) -> america
# continue (VBP) -> continue
# fight (NN) -> fight
# freedom (NN) -> freedom
# vestige (FW) -> vestige
# resistance (NN) -> resistance
# remains (VBZ) -> remain
# deeply (RB) -> deeply
# conscious (JJ) -> conscious
# fact (NN) -> fact
# much (RB) -> much
# hard (JJ) -> hard
# fighting (VBG) -> fight
# still (RB) -> still
# ahead (RB) -> ahead
# us (PRP) -> u
# pay (VBP) -> pay
# heavy (JJ) -> heavy
# price (NN) -> price
# make (VBP) -> make
# complete (JJ) -> complete
# victory (NN) -> victory
# certain (JJ) -> certain
# america (NN) -> america
# never (RB) -> never
# become (VBN) -> become
# party (NN) -> party
# plan (NN) -> plan
# partial (JJ) -> partial
# victory (NN) -> victory
# settle (VB) -> settle
# merely (RB) -> merely
# another (DT) -> another
# temporary (JJ) -> temporary
# respite (NN) -> respite
# would (MD) -> would
# surely (RB) -> surely
# jeopardize (VB) -> jeopardize
# future (JJ) -> future
# security (NN) -> security
# world (NN) -> world
# demand (NN) -> demand
# surrender (NN) -> surrender
# traffic (NN) -> traffic
# breakers (NNS) -> breaker
# peace (VBP) -> peace
# terms (NNS) -> term
# peace (VBP) -> peace
# responsibility (NN) -> responsibility
# making (NN) -> making
# grave (VBP) -> grave
# rest (NN) -> rest
# defenders (NNS) -> defender
# peace (VBP) -> peace
# unconscious (JJ) -> unconscious
# dictates (NNS) -> dictate
# humanity (NN) -> humanity
# wish (JJ) -> wish
# see (VBP) -> see
# unnecessary (JJ) -> unnecessary
# unjustified (JJ) -> unjustified
# suffering (NN) -> suffering
# laws (NNS) -> law
# go (VBP) -> go
# man (NN) -> man
# violated (VBD) -> violate
# guilty (JJ) -> guilty
# must (MD) -> must
# go (VB) -> go
# unpunished (JJ) -> unpunished
# nothing (NN) -> nothing
# shall (MD) -> shall
# shake (VB) -> shake
# determination (NN) -> determination
# punish (JJ) -> punish
# war (NN) -> war
# criminals (NNS) -> criminal
# even (RB) -> even
# though (IN) -> though
# must (MD) -> must
# pursue (VB) -> pursue
# ends (NNS) -> end
# earth (JJ) -> earth
# lasting (VBG) -> last
# peace (NN) -> peace
# never (RB) -> never
# secured (VBN) -> secure
# permit (RB) -> permit
# dangerous (JJ) -> dangerous
# opponents (NNS) -> opponent
# plot (JJ) -> plot
# future (JJ) -> future
# wars (NNS) -> war
# impunity (NN) -> impunity
# mountain (VBP) -> mountain
# retreat (NN) -> retreat
# however (RB) -> however
# distant (JJ) -> distant
# shrinking (VBG) -> shrink
# world (NN) -> world
# futile (NN) -> futile
# seek (NN) -> seek
# safety (NN) -> safety
# behind (IN) -> behind
# geographical (JJ) -> geographical
# barriers (NNS) -> barrier
# real (JJ) -> real
# security (NN) -> security
# found (VBD) -> find
# law (NN) -> law
# justice (NN) -> justice
# america (RB) -> america
# labored (VBD) -> labor
# long (JJ) -> long
# hard (JJ) -> hard
# achieve (VBP) -> achieve
# social (JJ) -> social
# order (NN) -> order
# worthy (JJ) -> worthy
# great (JJ) -> great
# heritage (NN) -> heritage
# time (NN) -> time
# tremendous (JJ) -> tremendous
# progress (NN) -> progress
# made (VBD) -> make
# toward (IN) -> toward
# really (RB) -> really
# democratic (JJ) -> democratic
# way (NN) -> way
# life (NN) -> life
# let (VB) -> let
# assure (JJ) -> assure
# people (NNS) -> people
# america (VBP) -> america
# w (JJ) -> w
# ill (JJ) -> ill
# relaxation (NN) -> relaxation
# efforts (NNS) -> effort
# improve (VB) -> improve
# lot (NN) -> lot
# common (JJ) -> common
# people (NNS) -> people
# difficult (JJ) -> difficult
# days (NNS) -> day
# ahead (RB) -> ahead
# unquestionably (RB) -> unquestionably
# shall (MD) -> shall
# face (VB) -> face
# problems (NNS) -> problem
# staggering (VBG) -> stagger
# proportions (NNS) -> proportion
# however (RB) -> however
# faith (VBP) -> faith
# fathers (NNS) -> father
# hearts (NNS) -> heart
# fear (VBP) -> fear
# future (JJ) -> future
# battlefields (NNS) -> battlefield
# frequently (RB) -> frequently
# faced (VBD) -> face
# overwhelming (JJ) -> overwhelming
# odds (NNS) -> odds
# home (NN) -> home
# americans (NNS) -> american
# less (RBR) -> less
# resolute (JJ) -> resolute
# shall (MD) -> shall
# never (RB) -> never
# cease (VB) -> cease
# struggle (NN) -> struggle
# preserve (NN) -> preserve
# maintain (VBP) -> maintain
# american (JJ) -> american
# way (NN) -> way
# life (NN) -> life
# moment (NN) -> moment
# america (NN) -> america
# along (IN) -> along
# brave (JJ) -> brave
# allies (NNS) -> ally
# paying (VBG) -> pay
# heavy (JJ) -> heavy
# price (NN) -> price
# defense (NN) -> defense
# freedom (NN) -> freedom
# characteristic (JJ) -> characteristic
# energy (NN) -> energy
# assisting (VBG) -> assist
# liberation (NN) -> liberation
# entire (JJ) -> entire
# nations (NNS) -> nation
# gradually (RB) -> gradually
# shackles (VBZ) -> shackle
# slavery (NN) -> slavery
# broken (JJ) -> broken
# forces (NNS) -> force
# freedom (VBP) -> freedom
# us (PRP) -> u
# praying (VBG) -> pray
# speedy (JJ) -> speedy
# victory (NN) -> victory
# every (DT) -> every
# day (NN) -> day
# peace (NN) -> peace
# delayed (VBN) -> delay
# costs (NNS) -> cost
# terrible (JJ) -> terrible
# toll (JJ) -> toll
# armies (NNS) -> army
# liberation (NN) -> liberation
# today (NN) -> today
# bringing (VBG) -> bring
# end (NN) -> end
# hitler (NN) -> hitler
# ghastly (RB) -> ghastly
# threat (NN) -> threat
# dominate (JJ) -> dominate
# world (NN) -> world
# tokyo (NN) -> tokyo
# rocks (NNS) -> rock
# weight (VBD) -> weight
# bombs (NNS) -> bomb
# grand (JJ) -> grand
# strategy (NN) -> strategy
# united (JJ) -> united
# nations (NNS) -> nation
# war (NN) -> war
# determined (VBD) -> determine
# due (JJ) -> due
# small (JJ) -> small
# measure (NN) -> measure
# vision (NN) -> vision
# departed (VBD) -> depart
# commander (NN) -> commander
# chief (NN) -> chief
# carrying (VBG) -> carry
# part (NN) -> part
# strategy (NN) -> strategy
# able (JJ) -> able
# direction (NN) -> direction
# admiral (JJ) -> admiral
# leahy (NN) -> leahy
# general (JJ) -> general
# marshall (NN) -> marshall
# dmiral (JJ) -> dmiral
# king (VBG) -> king
# general (JJ) -> general
# arnold (RB) -> arnold
# general (JJ) -> general
# eisenhower (RBR) -> eisenhower
# admiral (JJ) -> admiral
# nimitz (JJ) -> nimitz
# general (JJ) -> general
# macarthur (NN) -> macarthur
# want (VBP) -> want
# entire (JJ) -> entire
# world (NN) -> world
# know (VBP) -> know
# direction (NN) -> direction
# must (MD) -> must
# unhampered (VB) -> unhampered
# debt (NN) -> debt
# heroic (NN) -> heroic
# men (NNS) -> men
# valiant (JJ) -> valiant
# women (NNS) -> woman
# service (NN) -> service
# country (NN) -> country
# never (RB) -> never
# repaid (VBD) -> repay
# earned (VBN) -> earn
# undying (JJ) -> undying
# gratitude (NN) -> gratitude
# america (NN) -> america
# never (RB) -> never
# forget (VB) -> forget
# sacrifices (NNS) -> sacrifice
# sacrifices (NNS) -> sacrifice
# dawn (NN) -> dawn
# justice (NN) -> justice
# freedom (NN) -> freedom
# throughout (IN) -> throughout
# th (NN) -> th
# e (NN) -> e
# world (NN) -> world
# slowly (RB) -> slowly
# casts (VBZ) -> cast
# gleam (NN) -> gleam
# across (IN) -> across
# horizon (NN) -> horizon
# forefathers (NNS) -> forefather
# came (VBD) -> come
# rugged (JJ) -> rugged
# shores (NNS) -> shore
# search (VBP) -> search
# religious (JJ) -> religious
# tolerance (NN) -> tolerance
# political (JJ) -> political
# freedom (NN) -> freedom
# economic (JJ) -> economic
# opportunity (NN) -> opportunity
# fundamental (JJ) -> fundamental
# rights (NNS) -> right
# risked (VBN) -> risk
# lives (VBZ) -> live
# well (RB) -> well
# know (VB) -> know
# today (NN) -> today
# rights (NNS) -> right
# preserved (VBN) -> preserve
# constant (JJ) -> constant
# vigilance (NN) -> vigilance
# eternal (JJ) -> eternal
# price (NN) -> price
# liberty (NN) -> liberty
# within (IN) -> within
# hour (NN) -> hour
# took (VBD) -> take
# oath (NN) -> oath
# office (NN) -> office
# announced (VBD) -> announce
# san (JJ) -> san
# francisco (JJ) -> francisco
# conference (NN) -> conference
# would (MD) -> would
# proceed (VB) -> proceed
# face (NN) -> face
# problems (NNS) -> problem
# peace (VBP) -> peace
# courage (NN) -> courage
# faced (VBD) -> face
# mastered (JJ) -> mastered
# problems (NNS) -> problem
# war (NN) -> war
# memory (NN) -> memory
# made (VBD) -> make
# supreme (JJ) -> supreme
# memory (NN) -> memory
# fallen (VBN) -> fall
# shall (MD) -> shall
# fail (VB) -> fail
# enough (JJ) -> enough
# yearn (JJ) -> yearn
# peace (NN) -> peace
# must (MD) -> must
# work (VB) -> work
# necessary (JJ) -> necessary
# fight (NN) -> fight
# task (NN) -> task
# creating (VBG) -> create
# sound (JJ) -> sound
# international (JJ) -> international
# organization (NN) -> organization
# complicated (VBN) -> complicate
# difficult (JJ) -> difficult
# yet (RB) -> yet
# without (IN) -> without
# organization (NN) -> organization
# rights (NNS) -> right
# man (NN) -> man
# earth (NN) -> earth
# protected (VBD) -> protect
# machi (JJ) -> machi
# nery (NN) -> nery
# settlement (NN) -> settlement
# international (JJ) -> international
# differences (NNS) -> difference
# must (MD) -> must
# found (VB) -> find
# without (IN) -> without
# machinery (NN) -> machinery
# entire (JJ) -> entire
# world (NN) -> world
# remain (NN) -> remain
# armed (VBD) -> arm
# camp (JJ) -> camp
# world (NN) -> world
# doomed (VBD) -> doom
# deadly (JJ) -> deadly
# conflict (NN) -> conflict
# devoid (NN) -> devoid
# hope (VBP) -> hope
# real (JJ) -> real
# peace (NN) -> peace
# fortunately (RB) -> fortunately
# people (NNS) -> people
# retained (VBD) -> retain
# hope (RBR) -> hope
# durable (JJ) -> durable
# peace (NN) -> peace
# thoughtful (JJ) -> thoughtful
# people (NNS) -> people
# always (RB) -> always
# faith (VBP) -> faith
# ultimately (JJ) -> ultimately
# justice (NN) -> justice
# must (MD) -> must
# triumph (VB) -> triumph
# past (JJ) -> past
# experience (NN) -> experience
# surely (RB) -> surely
# indicates (VBZ) -> indicate
# without (IN) -> without
# justice (NN) -> justice
# enduring (VBG) -> endure
# peace (NN) -> peace
# becomes (VBZ) -> become
# impossible (JJ) -> impossible
# bitter (JJ) -> bitter
# despair (NN) -> despair
# people (NNS) -> people
# come (VBP) -> come
# believe (VBP) -> believe
# wars (NNS) -> war
# inevitable (JJ) -> inevitable
# tragic (JJ) -> tragic
# fatalism (NN) -> fatalism
# insist (NN) -> insist
# wars (NNS) -> war
# always (RB) -> always
# necessity (VBP) -> necessity
# necessity (NN) -> necessity
# wars (NNS) -> war
# always (RB) -> always
# defeatism (VBP) -> defeatism
# men (NNS) -> men
# women (NNS) -> woman
# good (JJ) -> good
# must (MD) -> must
# yield (VB) -> yield
# outlook (NN) -> outlook
# humanity (NN) -> humanity
# hopeless (NN) -> hopeless
# dark (NN) -> dark
# hours (NNS) -> hour
# horrible (JJ) -> horrible
# war (NN) -> war
# entire (JJ) -> entire
# nations (NNS) -> nation
# kept (VBD) -> keep
# going (VBG) -> go
# something (NN) -> something
# warned (VBD) -> warn
# abject (JJ) -> abject
# submission (NN) -> submission
# offered (VBN) -> offer
# salvation (NN) -> salvation
# overwhelming (VBG) -> overwhelm
# power (NN) -> power
# hope (NN) -> hope
# showed (VBD) -> show
# way (NN) -> way
# victory (NN) -> victory
# hope (VBP) -> hope
# become (VBN) -> become
# secret (JJ) -> secret
# weapon (NN) -> weapon
# forces (NNS) -> force
# liberation (NN) -> liberation
# aggressors (NNS) -> aggressor
# could (MD) -> could
# dominate (VB) -> dominate
# human (JJ) -> human
# mind (NN) -> mind
# long (JJ) -> long
# hope (NN) -> hope
# remains (VBZ) -> remain
# spirit (JJ) -> spirit
# man (NN) -> man
# never (RB) -> never
# crushed (VBD) -> crush
# hope (NN) -> hope
# alone (RB) -> alone
# sufficient (JJ) -> sufficient
# avert (JJ) -> avert
# war (NN) -> war
# must (MD) -> must
# hope (VB) -> hope
# must (MD) -> must
# faith (VB) -> faith
# enough (JJ) -> enough
# work (NN) -> work
# nations (NNS) -> nation
# maintain (VBP) -> maintain
# peace (NN) -> peace
# hope (VBP) -> hope
# enough (RB) -> enough
# beat (JJ) -> beat
# back (RP) -> back
# aggressors (NNS) -> aggressor
# long (JJ) -> long
# nations (NNS) -> nation
# unwilling (JJ) -> unwilling
# come (VBP) -> come
# defense (NN) -> defense
# aggressors (NNS) -> aggressor
# beaten (VBP) -> beat
# back (RP) -> back
# nations (NNS) -> nation
# united (JJ) -> united
# defend (VBP) -> defend
# wars (NNS) -> war
# future (JJ) -> future
# prevented (VBN) -> prevent
# nations (NNS) -> nation
# must (MD) -> must
# united (VBN) -> unite
# determination (NN) -> determination
# keep (VB) -> keep
# peace (NN) -> peace
# law (NN) -> law
# nothing (NN) -> nothing
# essential (JJ) -> essential
# future (NN) -> future
# peace (NN) -> peace
# world (NN) -> world
# continued (VBD) -> continue
# cooperation (NN) -> cooperation
# nations (NNS) -> nation
# muster (VBP) -> muster
# force (NN) -> force
# necessary (JJ) -> necessary
# defeat (NN) -> defeat
# conspiracy (NN) -> conspiracy
# axis (JJ) -> axis
# powers (NNS) -> power
# dominate (VBP) -> dominate
# world (NN) -> world
# great (JJ) -> great
# states (NNS) -> state
# special (JJ) -> special
# responsibility (NN) -> responsibility
# enforce (NN) -> enforce
# peace (NN) -> peace
# responsibility (NN) -> responsibility
# based (VBN) -> base
# upon (IN) -> upon
# obligations (NNS) -> obligation
# resting (VBG) -> rest
# upon (IN) -> upon
# states (NNS) -> state
# large (JJ) -> large
# small (JJ) -> small
# use (NN) -> use
# force (NN) -> force
# international (JJ) -> international
# relations (NNS) -> relation
# except (IN) -> except
# defense (NN) -> defense
# law (NN) -> law
# respon (NN) -> respon
# sibility (NN) -> sibility
# great (JJ) -> great
# states (NNS) -> state
# serve (VBP) -> serve
# dominate (JJ) -> dominate
# world (NN) -> world
# build (NN) -> build
# foundation (NN) -> foundation
# enduring (VBG) -> endure
# peace (NN) -> peace
# must (MD) -> must
# work (VB) -> work
# harmony (NN) -> harmony
# friends (NNS) -> friend
# abroad (RB) -> abroad
# must (MD) -> must
# united (VB) -> unite
# support (NN) -> support
# people (NNS) -> people
# even (RB) -> even
# experienced (VBD) -> experience
# pilot (NN) -> pilot
# bring (VBG) -> bring
# ship (NN) -> ship
# safely (RB) -> safely
# harbor (JJ) -> harbor
# unless (IN) -> unless
# full (JJ) -> full
# cooperation (NN) -> cooperation
# crew (NN) -> crew
# benefit (NN) -> benefit
# every (DT) -> every
# individual (NN) -> individual
# must (MD) -> must
# duty (VB) -> duty
# appeal (NN) -> appeal
# every (DT) -> every
# american (JJ) -> american
# regardless (NN) -> regardless
# party (NN) -> party
# race (NN) -> race
# creed (NN) -> creed
# color (NN) -> color
# support (NN) -> support
# efforts (NNS) -> effort
# build (VBP) -> build
# strong (JJ) -> strong
# lasting (NN) -> lasting
# united (JJ) -> united
# nations (NNS) -> nation
# organization (NN) -> organization
# members (NNS) -> member
# congress (VBP) -> congress
# surely (RB) -> surely
# know (VBP) -> know
# feel (VB) -> feel
# help (JJ) -> help
# hope (VB) -> hope
# complete (JJ) -> complete
# one (CD) -> one
# greatest (JJS) -> great
# tasks (NNS) -> task
# ever (RB) -> ever
# assigned (VBN) -> assign
# public (JJ) -> public
# servant (JJ) -> servant
# divine (NN) -> divine
# guidance (NN) -> guidance
# help (NN) -> help
# find (VB) -> find
# new (JJ) -> new
# passage (NN) -> passage
# far (RB) -> far
# better (RBR) -> well
# world (NN) -> world
# kindly (RB) -> kindly
# friendly (JJ) -> friendly
# world (NN) -> world
# lasting (VBG) -> last
# peace (NN) -> peace
# confidence (NN) -> confidence
# depending (VBG) -> depend
# upon (IN) -> upon
# destroy (JJ) -> destroy
# greedy (NN) -> greedy
# tyrants (NNS) -> tyrant
# dreams (JJ) -> dreams
# world (NN) -> world
# domination (NN) -> domination
# continue (VBP) -> continue
# successive (JJ) -> successive
# generations (NNS) -> generation
# sacrifice (VBP) -> sacrifice
# finest (JJS) -> fine
# youth (NN) -> youth
# name (NN) -> name
# human (JJ) -> human
# decency (NN) -> decency
# civilization (NN) -> civilization
# rational (JJ) -> rational
# method (NN) -> method
# deciding (VBG) -> decide
# national (JJ) -> national
# differences (NNS) -> difference
# must (MD) -> must
# found (VB) -> find
# america (RB) -> america
# must (MD) -> must
# assist (VB) -> assist
# suffering (VBG) -> suffer
# humanity (NN) -> humanity
# back (RB) -> back
# along (IN) -> along
# path (NN) -> path
# peaceful (JJ) -> peaceful
# progress (NN) -> progress
# require (NN) -> require
# time (NN) -> time
# tolerance (NN) -> tolerance
# shall (MD) -> shall
# need (VB) -> need
# also (RB) -> also
# abiding (VBG) -> abide
# faith (JJ) -> faith
# people (NNS) -> people
# kind (NN) -> kind
# faith (JJ) -> faith
# courage (NN) -> courage
# franklin (NN) -> franklin
# delano (NN) -> delano
# roosevelt (VBD) -> roosevelt
# always (RB) -> always
# today (NN) -> today
# america (VBD) -> america
# become (VBP) -> become
# one (CD) -> one
# powerful (JJ) -> powerful
# forces (NNS) -> force
# good (JJ) -> good
# earth (NN) -> earth
# must (MD) -> must
# keep (VB) -> keep
# achieved (JJ) -> achieved
# world (NN) -> world
# leadership (NN) -> leadership
# depend (VBP) -> depend
# solely (RB) -> solely
# upon (IN) -> upon
# military (JJ) -> military
# naval (NN) -> naval
# might (MD) -> might
# learned (VB) -> learn
# fight (JJ) -> fight
# nations (NNS) -> nation
# common (JJ) -> common
# defense (NN) -> defense
# freedom (NN) -> freedom
# must (MD) -> must
# learn (VB) -> learn
# live (JJ) -> live
# nations (NNS) -> nation
# mutual (JJ) -> mutual
# good (JJ) -> good
# must (MD) -> must
# learn (VB) -> learn
# trade (NN) -> trade
# nations (NNS) -> nation
# may (MD) -> may
# mutual (JJ) -> mutual
# product (NN) -> product
# ion (NN) -> ion
# increased (VBD) -> increase
# employment (NN) -> employment
# better (NN) -> better
# standards (NNS) -> standard
# living (VBG) -> live
# throughout (IN) -> throughout
# world (NN) -> world
# may (MD) -> may
# americans (VB) -> americans
# live (JJ) -> live
# glorious (JJ) -> glorious
# heritage (NN) -> heritage
# way (NN) -> way
# america (NN) -> america
# may (MD) -> may
# well (RB) -> well
# lead (VB) -> lead
# world (NN) -> world
# peace (NN) -> peace
# prosperity (NN) -> prosperity
# moment (NN) -> moment
# heart (NN) -> heart
# prayer (NN) -> prayer
# assumed (VBD) -> assume
# heavy (JJ) -> heavy
# duties (NNS) -> duty
# humbly (RB) -> humbly
# pray (VBP) -> pray
# almighty (JJ) -> almighty
# god (NN) -> god
# words (NNS) -> word
# king (VBG) -> king
# solomon (JJ) -> solomon
# give (JJ) -> give
# therefore (NN) -> therefore
# thy (NN) -> thy
# servant (NN) -> servant
# understanding (JJ) -> understanding
# heart (NN) -> heart
# judge (NN) -> judge
# thy (JJ) -> thy
# people (NNS) -> people
# may (MD) -> may
# discern (VB) -> discern
# good (JJ) -> good
# bad (JJ) -> bad
# able (JJ) -> able
# judge (NN) -> judge
# thy (JJ) -> thy
# great (JJ) -> great
# people (NNS) -> people
# ask (VBP) -> ask
# good (JJ) -> good
# faithful (NN) -> faithful
# servant (JJ) -> servant
# lord (NN) -> lord
# people (NNS) -> people

# %% [markdown]
# # From Words to Subwords: Byte Pair Encoding (BPE)

# %% [markdown]
# So far, we have treated words as the basic unit of meaning.
# Modern NLP systems often go one step further and operate on subword units.
#
# One of the most common subword tokenization methods is Byte Pair Encoding (BPE).

# %% [markdown]
# In large corpora like the State of the Union addresses, word-level tokenization creates several problems:
#
# Rare words appear very infrequently
#
# New words appear over time (e.g. cybersecurity, biotechnology)
#
# Related words are treated as completely separate tokens
#
# Subword tokenization solves this by breaking words into frequently occurring pieces.

# %%
# We will use a small subset of real policy-related words that appear in State of the Union speeches.

words = [
    "democracy",
    "democratic",
    "democratization",
    "economy",
    "economic",
    "economics"
]

words
# At the word level, all of these are treated as separate tokens.
# Out:
# ['democracy',
#  'democratic',
#  'democratization',
#  'economy',
#  'economic',
#  'economics']

# %% [markdown]
# ## Step 1 – Character-Level Representation

# %% [markdown]
# BPE starts by representing each word as a sequence of characters
# (with a special end-of-word marker).

# %%
char_tokens = [list(word) + ["</w>"] for word in words]
char_tokens
# Out:
# [['d', 'e', 'm', 'o', 'c', 'r', 'a', 'c', 'y', '</w>'],
#  ['d', 'e', 'm', 'o', 'c', 'r', 'a', 't', 'i', 'c', '</w>'],
#  ['d',
#   'e',
#   'm',
#   'o',
#   'c',
#   'r',
#   'a',
#   't',
#   'i',
#   'z',
#   'a',
#   't',
#   'i',
#   'o',
#   'n',
#   '</w>'],
#  ['e', 'c', 'o', 'n', 'o', 'm', 'y', '</w>'],
#  ['e', 'c', 'o', 'n', 'o', 'm', 'i', 'c', '</w>'],
#  ['e', 'c', 'o', 'n', 'o', 'm', 'i', 'c', 's', '</w>']]

# %% [markdown]
# ## Step 2 – Count Frequent Character Pairs

# %% [markdown]
# BPE repeatedly merges the most frequent adjacent character pairs across the corpus.

# %%
from collections import Counter

pair_counts = Counter()

for word in char_tokens:
    for i in range(len(word) - 1):
        pair = (word[i], word[i+1])
        pair_counts[pair] += 1

pair_counts.most_common(10)
# Out:
# [(('o', 'n'), 4),
#  (('d', 'e'), 3),
#  (('e', 'm'), 3),
#  (('m', 'o'), 3),
#  (('o', 'c'), 3),
#  (('c', 'r'), 3),
#  (('r', 'a'), 3),
#  (('a', 't'), 3),
#  (('t', 'i'), 3),
#  (('i', 'c'), 3)]

# %% [markdown]
# ## Step 3 – Merge Frequent Pairs (Conceptual)

# %% [markdown]
# The most frequent pair is ('o', 'n').
# BPE merges it into a new token: "on".
#
# This process repeats many times, gradually forming meaningful subwords.

# %%
bpe_tokens_example = [
    ["democr", "acy</w>"],
    ["democr", "atic</w>"],
    ["democr", "atization</w>"],
    ["econ", "omy</w>"],
    ["econ", "omic</w>"],
    ["econ", "omics</w>"]
]

bpe_tokens_example
# Out:
# [['democr', 'acy</w>'],
#  ['democr', 'atic</w>'],
#  ['democr', 'atization</w>'],
#  ['econ', 'omy</w>'],
#  ['econ', 'omic</w>'],
#  ['econ', 'omics</w>']]
